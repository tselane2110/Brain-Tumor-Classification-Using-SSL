# %% [markdown]
# <a href="https://colab.research.google.com/github/tselane2110/Brain-Tumor-Classification-Using-SSL/blob/main/implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Important Note
#
# In case you want to train your model and you wont be needing to perform any preprocessing of the data, go to `2. Training Phase 1 - Contrastive Learning` directly and dont run the cells under `Data loading & Preprocessing`.

# %% [markdown]
# ## 1. Data Loading & Preprocessing

# %%
# !git clone https://github.com/tselane2110/SSCLNet-Implementation
# Out:
# Cloning into 'SSCLNet-Implementation'...
# remote: Enumerating objects: 353, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 353 (delta 32), reused 14 (delta 8), pack-reused 297 (from 1)
# Receiving objects: 100% (353/353), 683.62 KiB | 2.98 MiB/s, done.
# Resolving deltas: 100% (200/200), done.

# %%
# %cd /content/SSCLNet-Implementation
# Out:
# /content/SSCLNet-Implementation

# %%
import dataset

# %%
dataset.load_data("https://drive.google.com/file/d/1Ke4oXJiZiUnomAwUfjjlmxzeI6HK1Zz4/view?usp=drive_link")
# Out:
# Downloading dataset...
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ke4oXJiZiUnomAwUfjjlmxzeI6HK1Zz4
# From (redirected): https://drive.google.com/uc?id=1Ke4oXJiZiUnomAwUfjjlmxzeI6HK1Zz4&confirm=t&uuid=15b8be63-fa48-4326-ba61-93b106a6d06c
# To: /content/dataset.zip
# 100%|██████████| 429M/429M [00:01<00:00, 287MB/s]
# Extracting dataset...
# Dataset ready at: /content/
# '/content/'

# %%
# moving dataset folder
# !mv /content/content/Dataset-Brain-MRI /content

# %%
# deleting the extra "content" folder
# !rm -r /content/content

# %%
# deleting the "duplicates_backup" folder from the "Dataset-Brain-MRI" folder, since we wont be using it anyways
# !rm -r /content/Dataset-Brain-MRI/duplicates_backup

# %%
dataset.split_data_disjoint_pretrain("/content/Dataset-Brain-MRI", "/content/splitted-dataset")

# %%
dataset.preprocess_split_data("/content/splitted-dataset", "/content/preprocessed-splitted-data")

# %%
# !zip -r "/content/preprocessed_splitted_data.zip" "/content/preprocessed-splitted-data"

# %% [markdown]
# * Downloaded the `preprocessed_splitted_data.zip` file manually and uploaded it to the gdrive folder.

# %% [markdown]
# ## 2. Training Phase 1 - Contrastive Learning

# %%
# !git clone https://github.com/tselane2110/SSCLNet-Implementation
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'SSCLNet-Implementation': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# loading the preprocessed-splitted dataset
# !gdown --fuzzy "https://drive.google.com/file/d/16qJoMaEM4VRIVqS7-iKwGfga-wq5x_lk/view?usp=drive_link"
# !unzip -q preprocessed_splitted_data.zip -d /
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=16qJoMaEM4VRIVqS7-iKwGfga-wq5x_lk
# From (redirected): https://drive.google.com/uc?id=16qJoMaEM4VRIVqS7-iKwGfga-wq5x_lk&confirm=t&uuid=7f0fa0c6-130b-4c22-99ff-60a609113361
# To: /content/SSCLNet-Implementation/preprocessed_splitted_data.zip
# 100% 153M/153M [00:00<00:00, 298MB/s]

# %%
# update file paths for pretrain and train data in the config.py file

# %%
# !python "/content/SSCLNet-Implementation/train_contrastive.py"
# Out:
# 2026-02-08 08:56:33.701736: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770540993.721237    2623 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770540993.727709    2623 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770540993.743077    2623 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770540993.743104    2623 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770540993.743107    2623 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770540993.743111    2623 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-08 08:56:33.747732: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✓ All directories created
# ✓ All directories created
# ✓ Random seed set to: 42
# 2026-02-08 08:56:38,702 - contrastive_pretraining - INFO - === Starting Contrastive Pre-training ===
# ================================================================================
# MODEL SUMMARY
# ================================================================================
# Model: SSCLNet
# Total trainable parameters: 25,669,524
# Model size: 98.12 MB
#
# Layer breakdown:
#   encoder.conv1.weight: 3,136
#   encoder.bn1.weight: 64
#   encoder.bn1.bias: 64
#   encoder.layer1.0.conv1.weight: 4,096
#   encoder.layer1.0.bn1.weight: 64
#   encoder.layer1.0.bn1.bias: 64
#   encoder.layer1.0.conv2.weight: 36,864
#   encoder.layer1.0.bn2.weight: 64
#   encoder.layer1.0.bn2.bias: 64
#   encoder.layer1.0.conv3.weight: 16,384
#   encoder.layer1.0.bn3.weight: 256
#   encoder.layer1.0.bn3.bias: 256
#   encoder.layer1.0.downsample.0.weight: 16,384
#   encoder.layer1.0.downsample.1.weight: 256
#   encoder.layer1.0.downsample.1.bias: 256
#   encoder.layer1.1.conv1.weight: 16,384
#   encoder.layer1.1.bn1.weight: 64
#   encoder.layer1.1.bn1.bias: 64
#   encoder.layer1.1.conv2.weight: 36,864
#   encoder.layer1.1.bn2.weight: 64
#   encoder.layer1.1.bn2.bias: 64
#   encoder.layer1.1.conv3.weight: 16,384
#   encoder.layer1.1.bn3.weight: 256
#   encoder.layer1.1.bn3.bias: 256
#   encoder.layer1.2.conv1.weight: 16,384
#   encoder.layer1.2.bn1.weight: 64
#   encoder.layer1.2.bn1.bias: 64
#   encoder.layer1.2.conv2.weight: 36,864
#   encoder.layer1.2.bn2.weight: 64
#   encoder.layer1.2.bn2.bias: 64
#   encoder.layer1.2.conv3.weight: 16,384
#   encoder.layer1.2.bn3.weight: 256
#   encoder.layer1.2.bn3.bias: 256
#   encoder.layer2.0.conv1.weight: 32,768
#   encoder.layer2.0.bn1.weight: 128
#   encoder.layer2.0.bn1.bias: 128
#   encoder.layer2.0.conv2.weight: 147,456
#   encoder.layer2.0.bn2.weight: 128
#   encoder.layer2.0.bn2.bias: 128
#   encoder.layer2.0.conv3.weight: 65,536
#   encoder.layer2.0.bn3.weight: 512
#   encoder.layer2.0.bn3.bias: 512
#   encoder.layer2.0.downsample.0.weight: 131,072
#   encoder.layer2.0.downsample.1.weight: 512
#   encoder.layer2.0.downsample.1.bias: 512
#   encoder.layer2.1.conv1.weight: 65,536
#   encoder.layer2.1.bn1.weight: 128
#   encoder.layer2.1.bn1.bias: 128
#   encoder.layer2.1.conv2.weight: 147,456
#   encoder.layer2.1.bn2.weight: 128
#   encoder.layer2.1.bn2.bias: 128
#   encoder.layer2.1.conv3.weight: 65,536
#   encoder.layer2.1.bn3.weight: 512
#   encoder.layer2.1.bn3.bias: 512
#   encoder.layer2.2.conv1.weight: 65,536
#   encoder.layer2.2.bn1.weight: 128
#   encoder.layer2.2.bn1.bias: 128
#   encoder.layer2.2.conv2.weight: 147,456
#   encoder.layer2.2.bn2.weight: 128
#   encoder.layer2.2.bn2.bias: 128
#   encoder.layer2.2.conv3.weight: 65,536
#   encoder.layer2.2.bn3.weight: 512
#   encoder.layer2.2.bn3.bias: 512
#   encoder.layer2.3.conv1.weight: 65,536
#   encoder.layer2.3.bn1.weight: 128
#   encoder.layer2.3.bn1.bias: 128
#   encoder.layer2.3.conv2.weight: 147,456
#   encoder.layer2.3.bn2.weight: 128
#   encoder.layer2.3.bn2.bias: 128
#   encoder.layer2.3.conv3.weight: 65,536
#   encoder.layer2.3.bn3.weight: 512
#   encoder.layer2.3.bn3.bias: 512
#   encoder.layer3.0.conv1.weight: 131,072
#   encoder.layer3.0.bn1.weight: 256
#   encoder.layer3.0.bn1.bias: 256
#   encoder.layer3.0.conv2.weight: 589,824
#   encoder.layer3.0.bn2.weight: 256
#   encoder.layer3.0.bn2.bias: 256
#   encoder.layer3.0.conv3.weight: 262,144
#   encoder.layer3.0.bn3.weight: 1,024
#   encoder.layer3.0.bn3.bias: 1,024
#   encoder.layer3.0.downsample.0.weight: 524,288
#   encoder.layer3.0.downsample.1.weight: 1,024
#   encoder.layer3.0.downsample.1.bias: 1,024
#   encoder.layer3.1.conv1.weight: 262,144
#   encoder.layer3.1.bn1.weight: 256
#   encoder.layer3.1.bn1.bias: 256
#   encoder.layer3.1.conv2.weight: 589,824
#   encoder.layer3.1.bn2.weight: 256
#   encoder.layer3.1.bn2.bias: 256
#   encoder.layer3.1.conv3.weight: 262,144
#   encoder.layer3.1.bn3.weight: 1,024
#   encoder.layer3.1.bn3.bias: 1,024
#   encoder.layer3.2.conv1.weight: 262,144
#   encoder.layer3.2.bn1.weight: 256
#   encoder.layer3.2.bn1.bias: 256
#   encoder.layer3.2.conv2.weight: 589,824
#   encoder.layer3.2.bn2.weight: 256
#   encoder.layer3.2.bn2.bias: 256
#   encoder.layer3.2.conv3.weight: 262,144
#   encoder.layer3.2.bn3.weight: 1,024
#   encoder.layer3.2.bn3.bias: 1,024
#   encoder.layer3.3.conv1.weight: 262,144
#   encoder.layer3.3.bn1.weight: 256
#   encoder.layer3.3.bn1.bias: 256
#   encoder.layer3.3.conv2.weight: 589,824
#   encoder.layer3.3.bn2.weight: 256
#   encoder.layer3.3.bn2.bias: 256
#   encoder.layer3.3.conv3.weight: 262,144
#   encoder.layer3.3.bn3.weight: 1,024
#   encoder.layer3.3.bn3.bias: 1,024
#   encoder.layer3.4.conv1.weight: 262,144
#   encoder.layer3.4.bn1.weight: 256
#   encoder.layer3.4.bn1.bias: 256
#   encoder.layer3.4.conv2.weight: 589,824
#   encoder.layer3.4.bn2.weight: 256
#   encoder.layer3.4.bn2.bias: 256
#   encoder.layer3.4.conv3.weight: 262,144
#   encoder.layer3.4.bn3.weight: 1,024
#   encoder.layer3.4.bn3.bias: 1,024
#   encoder.layer3.5.conv1.weight: 262,144
#   encoder.layer3.5.bn1.weight: 256
#   encoder.layer3.5.bn1.bias: 256
#   encoder.layer3.5.conv2.weight: 589,824
#   encoder.layer3.5.bn2.weight: 256
#   encoder.layer3.5.bn2.bias: 256
#   encoder.layer3.5.conv3.weight: 262,144
#   encoder.layer3.5.bn3.weight: 1,024
#   encoder.layer3.5.bn3.bias: 1,024
#   encoder.layer4.0.conv1.weight: 524,288
#   encoder.layer4.0.bn1.weight: 512
#   encoder.layer4.0.bn1.bias: 512
#   encoder.layer4.0.conv2.weight: 2,359,296
#   encoder.layer4.0.bn2.weight: 512
#   encoder.layer4.0.bn2.bias: 512
#   encoder.layer4.0.conv3.weight: 1,048,576
#   encoder.layer4.0.bn3.weight: 2,048
#   encoder.layer4.0.bn3.bias: 2,048
#   encoder.layer4.0.downsample.0.weight: 2,097,152
#   encoder.layer4.0.downsample.1.weight: 2,048
#   encoder.layer4.0.downsample.1.bias: 2,048
#   encoder.layer4.1.conv1.weight: 1,048,576
#   encoder.layer4.1.bn1.weight: 512
#   encoder.layer4.1.bn1.bias: 512
#   encoder.layer4.1.conv2.weight: 2,359,296
#   encoder.layer4.1.bn2.weight: 512
#   encoder.layer4.1.bn2.bias: 512
#   encoder.layer4.1.conv3.weight: 1,048,576
#   encoder.layer4.1.bn3.weight: 2,048
#   encoder.layer4.1.bn3.bias: 2,048
#   encoder.layer4.2.conv1.weight: 1,048,576
#   encoder.layer4.2.bn1.weight: 512
#   encoder.layer4.2.bn1.bias: 512
#   encoder.layer4.2.conv2.weight: 2,359,296
#   encoder.layer4.2.bn2.weight: 512
#   encoder.layer4.2.bn2.bias: 512
#   encoder.layer4.2.conv3.weight: 1,048,576
#   encoder.layer4.2.bn3.weight: 2,048
#   encoder.layer4.2.bn3.bias: 2,048
#   projection_head.mlp.0.weight: 1,048,576
#   projection_head.mlp.0.bias: 512
#   projection_head.mlp.2.weight: 262,144
#   projection_head.mlp.2.bias: 512
#   projection_head.mlp.4.weight: 131,072
#   projection_head.mlp.4.bias: 256
#   projection_head.mlp.6.weight: 65,536
#   projection_head.mlp.6.bias: 256
#   projection_head.mlp.9.weight: 8,192
#   projection_head.mlp.9.bias: 32
#   classifier.classifier.0.weight: 524,288
#   classifier.classifier.0.bias: 256
#   classifier.classifier.2.weight: 65,536
#   classifier.classifier.2.bias: 256
#   classifier.classifier.4.weight: 32,768
#   classifier.classifier.4.bias: 128
#   classifier.classifier.6.weight: 16,384
#   classifier.classifier.6.bias: 128
#   classifier.classifier.8.weight: 8,192
#   classifier.classifier.8.bias: 64
#   classifier.classifier.10.weight: 2,048
#   classifier.classifier.10.bias: 32
#   classifier.classifier.12.weight: 512
#   classifier.classifier.12.bias: 16
#   classifier.classifier.14.weight: 64
#   classifier.classifier.14.bias: 4
# ================================================================================
# Created pretrain DataLoader:
#   - Batch size: 64
#   - Shuffle: True
#   - Workers: 2
#   - Augmentation pool: random_cropping, random_brightness, random_contrast, random_noise
#   - Number of samples: 7666
#   - Returns: (augmented_image1, augmented_image2) pairs
# 2026-02-08 08:56:39,395 - contrastive_pretraining - INFO - Pre-training with 7666 unlabeled images
# Epoch 1/100:   0% 0/120 [00:03<?, ?it/s, Loss=4.8528]2026-02-08 08:56:43,332 - contrastive_pretraining - INFO - Epoch 0 - contrastive_loss/batch: 4.8528
# 2026-02-08 08:56:43,333 - contrastive_pretraining - INFO - Epoch 0 - learning_rate: 0.0003
# Epoch 1/100:  18% 21/120 [00:27<02:09,  1.31s/it, Loss=3.7344]
# Traceback (most recent call last):
#   File "/content/SSCLNet-Implementation/train_contrastive.py", line 109, in <module>
#     train_contrastive()
#   File "/content/SSCLNet-Implementation/train_contrastive.py", line 63, in train_contrastive
#     loss.backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 625, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 354, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 841, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# downloading the output
# !zip -r contrastive_training_output.zip /content/contrastive_training_output

# %% [markdown]
# ## 3. Training Phase 2 - Supervised Learning (4-class dataset)

# %%
# !git clone https://github.com/tselane2110/SSCLNet-Implementation

# %%
# loading the dataset
# !gdown --fuzzy "https://drive.google.com/file/d/16-v8HBPN_Nnj8JnQSDRSnfq5C1YqD-8y/view?usp=drive_link"
# !unzip -q /content/Preprocessed-splitted-data.zip

# %%
# !python "/content/SSCLNet-Implementation/train_supervised.py"
# Out:
# 2025-11-29 11:10:14.349743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764414614.381184   67567 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764414614.390953   67567 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764414614.414505   67567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764414614.414555   67567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764414614.414565   67567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764414614.414572   67567 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-29 11:10:14.421306: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✓ All directories created
# ✓ All directories created
# ✓ Random seed set to: 42
# 2025-11-29 11:10:19,044 - supervised_finetuning - INFO - === Starting TWO-STAGE Supervised Fine-tuning ===
# ✓ It's a model file - loading directly
# 2025-11-29 11:10:19,692 - supervised_finetuning - INFO - ✓ Loaded pre-trained weights from contrastive training!
# ================================================================================
# MODEL SUMMARY
# ================================================================================
# Model: SSCLNet
# Total trainable parameters: 25,669,524
# Model size: 98.12 MB
#
# Layer breakdown:
#   encoder.conv1.weight: 3,136
#   encoder.bn1.weight: 64
#   encoder.bn1.bias: 64
#   encoder.layer1.0.conv1.weight: 4,096
#   encoder.layer1.0.bn1.weight: 64
#   encoder.layer1.0.bn1.bias: 64
#   encoder.layer1.0.conv2.weight: 36,864
#   encoder.layer1.0.bn2.weight: 64
#   encoder.layer1.0.bn2.bias: 64
#   encoder.layer1.0.conv3.weight: 16,384
#   encoder.layer1.0.bn3.weight: 256
#   encoder.layer1.0.bn3.bias: 256
#   encoder.layer1.0.downsample.0.weight: 16,384
#   encoder.layer1.0.downsample.1.weight: 256
#   encoder.layer1.0.downsample.1.bias: 256
#   encoder.layer1.1.conv1.weight: 16,384
#   encoder.layer1.1.bn1.weight: 64
#   encoder.layer1.1.bn1.bias: 64
#   encoder.layer1.1.conv2.weight: 36,864
#   encoder.layer1.1.bn2.weight: 64
#   encoder.layer1.1.bn2.bias: 64
#   encoder.layer1.1.conv3.weight: 16,384
#   encoder.layer1.1.bn3.weight: 256
#   encoder.layer1.1.bn3.bias: 256
#   encoder.layer1.2.conv1.weight: 16,384
#   encoder.layer1.2.bn1.weight: 64
#   encoder.layer1.2.bn1.bias: 64
#   encoder.layer1.2.conv2.weight: 36,864
#   encoder.layer1.2.bn2.weight: 64
#   encoder.layer1.2.bn2.bias: 64
#   encoder.layer1.2.conv3.weight: 16,384
#   encoder.layer1.2.bn3.weight: 256
#   encoder.layer1.2.bn3.bias: 256
#   encoder.layer2.0.conv1.weight: 32,768
#   encoder.layer2.0.bn1.weight: 128
#   encoder.layer2.0.bn1.bias: 128
#   encoder.layer2.0.conv2.weight: 147,456
#   encoder.layer2.0.bn2.weight: 128
#   encoder.layer2.0.bn2.bias: 128
#   encoder.layer2.0.conv3.weight: 65,536
#   encoder.layer2.0.bn3.weight: 512
#   encoder.layer2.0.bn3.bias: 512
#   encoder.layer2.0.downsample.0.weight: 131,072
#   encoder.layer2.0.downsample.1.weight: 512
#   encoder.layer2.0.downsample.1.bias: 512
#   encoder.layer2.1.conv1.weight: 65,536
#   encoder.layer2.1.bn1.weight: 128
#   encoder.layer2.1.bn1.bias: 128
#   encoder.layer2.1.conv2.weight: 147,456
#   encoder.layer2.1.bn2.weight: 128
#   encoder.layer2.1.bn2.bias: 128
#   encoder.layer2.1.conv3.weight: 65,536
#   encoder.layer2.1.bn3.weight: 512
#   encoder.layer2.1.bn3.bias: 512
#   encoder.layer2.2.conv1.weight: 65,536
#   encoder.layer2.2.bn1.weight: 128
#   encoder.layer2.2.bn1.bias: 128
#   encoder.layer2.2.conv2.weight: 147,456
#   encoder.layer2.2.bn2.weight: 128
#   encoder.layer2.2.bn2.bias: 128
#   encoder.layer2.2.conv3.weight: 65,536
#   encoder.layer2.2.bn3.weight: 512
#   encoder.layer2.2.bn3.bias: 512
#   encoder.layer2.3.conv1.weight: 65,536
#   encoder.layer2.3.bn1.weight: 128
#   encoder.layer2.3.bn1.bias: 128
#   encoder.layer2.3.conv2.weight: 147,456
#   encoder.layer2.3.bn2.weight: 128
#   encoder.layer2.3.bn2.bias: 128
#   encoder.layer2.3.conv3.weight: 65,536
#   encoder.layer2.3.bn3.weight: 512
#   encoder.layer2.3.bn3.bias: 512
#   encoder.layer3.0.conv1.weight: 131,072
#   encoder.layer3.0.bn1.weight: 256
#   encoder.layer3.0.bn1.bias: 256
#   encoder.layer3.0.conv2.weight: 589,824
#   encoder.layer3.0.bn2.weight: 256
#   encoder.layer3.0.bn2.bias: 256
#   encoder.layer3.0.conv3.weight: 262,144
#   encoder.layer3.0.bn3.weight: 1,024
#   encoder.layer3.0.bn3.bias: 1,024
#   encoder.layer3.0.downsample.0.weight: 524,288
#   encoder.layer3.0.downsample.1.weight: 1,024
#   encoder.layer3.0.downsample.1.bias: 1,024
#   encoder.layer3.1.conv1.weight: 262,144
#   encoder.layer3.1.bn1.weight: 256
#   encoder.layer3.1.bn1.bias: 256
#   encoder.layer3.1.conv2.weight: 589,824
#   encoder.layer3.1.bn2.weight: 256
#   encoder.layer3.1.bn2.bias: 256
#   encoder.layer3.1.conv3.weight: 262,144
#   encoder.layer3.1.bn3.weight: 1,024
#   encoder.layer3.1.bn3.bias: 1,024
#   encoder.layer3.2.conv1.weight: 262,144
#   encoder.layer3.2.bn1.weight: 256
#   encoder.layer3.2.bn1.bias: 256
#   encoder.layer3.2.conv2.weight: 589,824
#   encoder.layer3.2.bn2.weight: 256
#   encoder.layer3.2.bn2.bias: 256
#   encoder.layer3.2.conv3.weight: 262,144
#   encoder.layer3.2.bn3.weight: 1,024
#   encoder.layer3.2.bn3.bias: 1,024
#   encoder.layer3.3.conv1.weight: 262,144
#   encoder.layer3.3.bn1.weight: 256
#   encoder.layer3.3.bn1.bias: 256
#   encoder.layer3.3.conv2.weight: 589,824
#   encoder.layer3.3.bn2.weight: 256
#   encoder.layer3.3.bn2.bias: 256
#   encoder.layer3.3.conv3.weight: 262,144
#   encoder.layer3.3.bn3.weight: 1,024
#   encoder.layer3.3.bn3.bias: 1,024
#   encoder.layer3.4.conv1.weight: 262,144
#   encoder.layer3.4.bn1.weight: 256
#   encoder.layer3.4.bn1.bias: 256
#   encoder.layer3.4.conv2.weight: 589,824
#   encoder.layer3.4.bn2.weight: 256
#   encoder.layer3.4.bn2.bias: 256
#   encoder.layer3.4.conv3.weight: 262,144
#   encoder.layer3.4.bn3.weight: 1,024
#   encoder.layer3.4.bn3.bias: 1,024
#   encoder.layer3.5.conv1.weight: 262,144
#   encoder.layer3.5.bn1.weight: 256
#   encoder.layer3.5.bn1.bias: 256
#   encoder.layer3.5.conv2.weight: 589,824
#   encoder.layer3.5.bn2.weight: 256
#   encoder.layer3.5.bn2.bias: 256
#   encoder.layer3.5.conv3.weight: 262,144
#   encoder.layer3.5.bn3.weight: 1,024
#   encoder.layer3.5.bn3.bias: 1,024
#   encoder.layer4.0.conv1.weight: 524,288
#   encoder.layer4.0.bn1.weight: 512
#   encoder.layer4.0.bn1.bias: 512
#   encoder.layer4.0.conv2.weight: 2,359,296
#   encoder.layer4.0.bn2.weight: 512
#   encoder.layer4.0.bn2.bias: 512
#   encoder.layer4.0.conv3.weight: 1,048,576
#   encoder.layer4.0.bn3.weight: 2,048
#   encoder.layer4.0.bn3.bias: 2,048
#   encoder.layer4.0.downsample.0.weight: 2,097,152
#   encoder.layer4.0.downsample.1.weight: 2,048
#   encoder.layer4.0.downsample.1.bias: 2,048
#   encoder.layer4.1.conv1.weight: 1,048,576
#   encoder.layer4.1.bn1.weight: 512
#   encoder.layer4.1.bn1.bias: 512
#   encoder.layer4.1.conv2.weight: 2,359,296
#   encoder.layer4.1.bn2.weight: 512
#   encoder.layer4.1.bn2.bias: 512
#   encoder.layer4.1.conv3.weight: 1,048,576
#   encoder.layer4.1.bn3.weight: 2,048
#   encoder.layer4.1.bn3.bias: 2,048
#   encoder.layer4.2.conv1.weight: 1,048,576
#   encoder.layer4.2.bn1.weight: 512
#   encoder.layer4.2.bn1.bias: 512
#   encoder.layer4.2.conv2.weight: 2,359,296
#   encoder.layer4.2.bn2.weight: 512
#   encoder.layer4.2.bn2.bias: 512
#   encoder.layer4.2.conv3.weight: 1,048,576
#   encoder.layer4.2.bn3.weight: 2,048
#   encoder.layer4.2.bn3.bias: 2,048
#   projection_head.mlp.0.weight: 1,048,576
#   projection_head.mlp.0.bias: 512
#   projection_head.mlp.2.weight: 262,144
#   projection_head.mlp.2.bias: 512
#   projection_head.mlp.4.weight: 131,072
#   projection_head.mlp.4.bias: 256
#   projection_head.mlp.6.weight: 65,536
#   projection_head.mlp.6.bias: 256
#   projection_head.mlp.9.weight: 8,192
#   projection_head.mlp.9.bias: 32
#   classifier.classifier.0.weight: 524,288
#   classifier.classifier.0.bias: 256
#   classifier.classifier.2.weight: 65,536
#   classifier.classifier.2.bias: 256
#   classifier.classifier.4.weight: 32,768
#   classifier.classifier.4.bias: 128
#   classifier.classifier.6.weight: 16,384
#   classifier.classifier.6.bias: 128
#   classifier.classifier.8.weight: 8,192
#   classifier.classifier.8.bias: 64
#   classifier.classifier.10.weight: 2,048
#   classifier.classifier.10.bias: 32
#   classifier.classifier.12.weight: 512
#   classifier.classifier.12.bias: 16
#   classifier.classifier.14.weight: 64
#   classifier.classifier.14.bias: 4
# ================================================================================
# 2025-11-29 11:10:19,738 - supervised_finetuning - INFO - ✓ Encoder frozen - only classifier will be trained
# Created train DataLoader:
#   - Batch size: 64
#   - Shuffle: True
#   - Workers: 2
#   - Classes: ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
#   - Number of samples: 1015
# ==================================================
# DATASET ANALYSIS
# ==================================================
# Total samples: 1015
# Class distribution:
#   meningioma_tumor: 244 (24.0%)
#   pituitary_tumor: 199 (19.6%)
#   glioma_tumor: 429 (42.3%)
#   no_tumor: 143 (14.1%)
# 2025-11-29 11:10:20,939 - supervised_finetuning - INFO - Training with 1015 labeled images
# 2025-11-29 11:10:20,939 - supervised_finetuning - INFO - === STAGE 1: Extracting Label Features ===
# Extracting features: 100% 16/16 [00:03<00:00,  4.88it/s]
# 2025-11-29 11:10:24,229 - supervised_finetuning - INFO - ✓ Extracted 1015 label features with shape torch.Size([1015, 2048])
# 2025-11-29 11:10:24,229 - supervised_finetuning - INFO - ✓ Created feature dataset for classifier training
# 2025-11-29 11:10:24,229 - supervised_finetuning - INFO - === STAGE 2: Training Classifier on Label Features ===
# Classifier Epoch 1/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.4420, Acc=25.00%]2025-11-29 11:10:24,378 - supervised_finetuning - INFO - Epoch 0 - supervised_loss/batch: 1.4420
# 2025-11-29 11:10:24,378 - supervised_finetuning - INFO - Epoch 0 - supervised_accuracy/batch: 25.0000
# 2025-11-29 11:10:24,379 - supervised_finetuning - INFO - Epoch 0 - learning_rate: 0.0001
# Classifier Epoch 1/100:   6% 1/16 [00:00<00:02,  6.70it/s, Loss=1.4470, Acc=15.62%]2025-11-29 11:10:24,414 - supervised_finetuning - INFO - Epoch 10 - supervised_loss/batch: 1.4470
# 2025-11-29 11:10:24,414 - supervised_finetuning - INFO - Epoch 10 - supervised_accuracy/batch: 15.6250
# 2025-11-29 11:10:24,414 - supervised_finetuning - INFO - Epoch 10 - learning_rate: 0.0001
# Classifier Epoch 1/100: 100% 16/16 [00:00<00:00, 74.35it/s, Loss=1.4431, Acc=23.64%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:24,502 - supervised_finetuning - INFO - Epoch 1:
# 2025-11-29 11:10:24,507 - supervised_finetuning - INFO -   Train Loss: 1.4415, Train Acc: 24.04%
# 2025-11-29 11:10:24,507 - supervised_finetuning - INFO -   Train F1: 9.32%, Train Recall: 24.04%
# 2025-11-29 11:10:24,507 - supervised_finetuning - INFO -   Train Precision: 5.78%
# 2025-11-29 11:10:24,507 - supervised_finetuning - INFO - Epoch 0 - supervised_loss/epoch: 1.4415
# 2025-11-29 11:10:24,508 - supervised_finetuning - INFO - Epoch 0 - supervised_accuracy/epoch: 24.0394
# 2025-11-29 11:10:24,508 - supervised_finetuning - INFO - Epoch 0 - supervised_f1/epoch: 9.3179
# 2025-11-29 11:10:24,508 - supervised_finetuning - INFO - Epoch 0 - supervised_recall/epoch: 24.0394
# 2025-11-29 11:10:24,508 - supervised_finetuning - INFO - Epoch 0 - supervised_precision/epoch: 5.7789
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:25,192 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 24.04%
# Classifier Epoch 2/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.3835, Acc=39.06%]2025-11-29 11:10:25,197 - supervised_finetuning - INFO - Epoch 16 - supervised_loss/batch: 1.3835
# 2025-11-29 11:10:25,198 - supervised_finetuning - INFO - Epoch 16 - supervised_accuracy/batch: 39.0625
# 2025-11-29 11:10:25,198 - supervised_finetuning - INFO - Epoch 16 - learning_rate: 0.0001
# Classifier Epoch 2/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.4622, Acc=14.06%]2025-11-29 11:10:25,232 - supervised_finetuning - INFO - Epoch 26 - supervised_loss/batch: 1.4622
# 2025-11-29 11:10:25,232 - supervised_finetuning - INFO - Epoch 26 - supervised_accuracy/batch: 14.0625
# 2025-11-29 11:10:25,232 - supervised_finetuning - INFO - Epoch 26 - learning_rate: 0.0001
# Classifier Epoch 2/100: 100% 16/16 [00:00<00:00, 281.34it/s, Loss=1.4509, Acc=27.27%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:25,259 - supervised_finetuning - INFO - Epoch 2:
# 2025-11-29 11:10:25,259 - supervised_finetuning - INFO -   Train Loss: 1.4329, Train Acc: 24.04%
# 2025-11-29 11:10:25,259 - supervised_finetuning - INFO -   Train F1: 9.32%, Train Recall: 24.04%
# 2025-11-29 11:10:25,259 - supervised_finetuning - INFO -   Train Precision: 5.78%
# 2025-11-29 11:10:25,259 - supervised_finetuning - INFO - Epoch 1 - supervised_loss/epoch: 1.4329
# 2025-11-29 11:10:25,260 - supervised_finetuning - INFO - Epoch 1 - supervised_accuracy/epoch: 24.0394
# 2025-11-29 11:10:25,260 - supervised_finetuning - INFO - Epoch 1 - supervised_f1/epoch: 9.3179
# 2025-11-29 11:10:25,260 - supervised_finetuning - INFO - Epoch 1 - supervised_recall/epoch: 24.0394
# 2025-11-29 11:10:25,260 - supervised_finetuning - INFO - Epoch 1 - supervised_precision/epoch: 5.7789
# Classifier Epoch 3/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.4266, Acc=21.88%]2025-11-29 11:10:25,264 - supervised_finetuning - INFO - Epoch 32 - supervised_loss/batch: 1.4266
# 2025-11-29 11:10:25,265 - supervised_finetuning - INFO - Epoch 32 - supervised_accuracy/batch: 21.8750
# 2025-11-29 11:10:25,265 - supervised_finetuning - INFO - Epoch 32 - learning_rate: 0.0001
# Classifier Epoch 3/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.4095, Acc=17.19%]2025-11-29 11:10:25,301 - supervised_finetuning - INFO - Epoch 42 - supervised_loss/batch: 1.4095
# 2025-11-29 11:10:25,301 - supervised_finetuning - INFO - Epoch 42 - supervised_accuracy/batch: 17.1875
# 2025-11-29 11:10:25,301 - supervised_finetuning - INFO - Epoch 42 - learning_rate: 0.0001
# Classifier Epoch 3/100: 100% 16/16 [00:00<00:00, 276.07it/s, Loss=1.4425, Acc=18.18%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:25,327 - supervised_finetuning - INFO - Epoch 3:
# 2025-11-29 11:10:25,327 - supervised_finetuning - INFO -   Train Loss: 1.4208, Train Acc: 24.04%
# 2025-11-29 11:10:25,327 - supervised_finetuning - INFO -   Train F1: 9.32%, Train Recall: 24.04%
# 2025-11-29 11:10:25,327 - supervised_finetuning - INFO -   Train Precision: 5.78%
# 2025-11-29 11:10:25,327 - supervised_finetuning - INFO - Epoch 2 - supervised_loss/epoch: 1.4208
# 2025-11-29 11:10:25,328 - supervised_finetuning - INFO - Epoch 2 - supervised_accuracy/epoch: 24.0394
# 2025-11-29 11:10:25,328 - supervised_finetuning - INFO - Epoch 2 - supervised_f1/epoch: 9.3179
# 2025-11-29 11:10:25,328 - supervised_finetuning - INFO - Epoch 2 - supervised_recall/epoch: 24.0394
# 2025-11-29 11:10:25,328 - supervised_finetuning - INFO - Epoch 2 - supervised_precision/epoch: 5.7789
# Classifier Epoch 4/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.4054, Acc=23.44%]2025-11-29 11:10:25,335 - supervised_finetuning - INFO - Epoch 48 - supervised_loss/batch: 1.4054
# 2025-11-29 11:10:25,335 - supervised_finetuning - INFO - Epoch 48 - supervised_accuracy/batch: 23.4375
# 2025-11-29 11:10:25,335 - supervised_finetuning - INFO - Epoch 48 - learning_rate: 0.0001
# Classifier Epoch 4/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.3961, Acc=23.44%]2025-11-29 11:10:25,393 - supervised_finetuning - INFO - Epoch 58 - supervised_loss/batch: 1.3961
# 2025-11-29 11:10:25,394 - supervised_finetuning - INFO - Epoch 58 - supervised_accuracy/batch: 23.4375
# 2025-11-29 11:10:25,394 - supervised_finetuning - INFO - Epoch 58 - learning_rate: 0.0001
# Classifier Epoch 4/100: 100% 16/16 [00:00<00:00, 147.26it/s, Loss=1.3691, Acc=27.27%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:25,471 - supervised_finetuning - INFO - Epoch 4:
# 2025-11-29 11:10:25,471 - supervised_finetuning - INFO -   Train Loss: 1.4029, Train Acc: 24.04%
# 2025-11-29 11:10:25,472 - supervised_finetuning - INFO -   Train F1: 9.32%, Train Recall: 24.04%
# 2025-11-29 11:10:25,472 - supervised_finetuning - INFO -   Train Precision: 5.78%
# 2025-11-29 11:10:25,472 - supervised_finetuning - INFO - Epoch 3 - supervised_loss/epoch: 1.4029
# 2025-11-29 11:10:25,473 - supervised_finetuning - INFO - Epoch 3 - supervised_accuracy/epoch: 24.0394
# 2025-11-29 11:10:25,473 - supervised_finetuning - INFO - Epoch 3 - supervised_f1/epoch: 9.3179
# 2025-11-29 11:10:25,473 - supervised_finetuning - INFO - Epoch 3 - supervised_recall/epoch: 24.0394
# 2025-11-29 11:10:25,475 - supervised_finetuning - INFO - Epoch 3 - supervised_precision/epoch: 5.7789
# Classifier Epoch 5/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.3965, Acc=20.31%]2025-11-29 11:10:25,484 - supervised_finetuning - INFO - Epoch 64 - supervised_loss/batch: 1.3965
# 2025-11-29 11:10:25,484 - supervised_finetuning - INFO - Epoch 64 - supervised_accuracy/batch: 20.3125
# 2025-11-29 11:10:25,485 - supervised_finetuning - INFO - Epoch 64 - learning_rate: 0.0001
# Classifier Epoch 5/100:  56% 9/16 [00:00<00:00, 89.49it/s, Loss=1.3298, Acc=31.25%]2025-11-29 11:10:25,586 - supervised_finetuning - INFO - Epoch 74 - supervised_loss/batch: 1.3298
# 2025-11-29 11:10:25,586 - supervised_finetuning - INFO - Epoch 74 - supervised_accuracy/batch: 31.2500
# 2025-11-29 11:10:25,586 - supervised_finetuning - INFO - Epoch 74 - learning_rate: 0.0001
# Classifier Epoch 5/100: 100% 16/16 [00:00<00:00, 117.52it/s, Loss=1.2849, Acc=47.27%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:25,655 - supervised_finetuning - INFO - Epoch 5:
# 2025-11-29 11:10:25,655 - supervised_finetuning - INFO -   Train Loss: 1.3462, Train Acc: 32.51%
# 2025-11-29 11:10:25,655 - supervised_finetuning - INFO -   Train F1: 26.18%, Train Recall: 32.51%
# 2025-11-29 11:10:25,659 - supervised_finetuning - INFO -   Train Precision: 27.43%
# 2025-11-29 11:10:25,660 - supervised_finetuning - INFO - Epoch 4 - supervised_loss/epoch: 1.3462
# 2025-11-29 11:10:25,661 - supervised_finetuning - INFO - Epoch 4 - supervised_accuracy/epoch: 32.5123
# 2025-11-29 11:10:25,663 - supervised_finetuning - INFO - Epoch 4 - supervised_f1/epoch: 26.1751
# 2025-11-29 11:10:25,664 - supervised_finetuning - INFO - Epoch 4 - supervised_recall/epoch: 32.5123
# 2025-11-29 11:10:25,666 - supervised_finetuning - INFO - Epoch 4 - supervised_precision/epoch: 27.4314
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:30,423 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 32.51%
# Classifier Epoch 6/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.2635, Acc=53.12%]2025-11-29 11:10:30,428 - supervised_finetuning - INFO - Epoch 80 - supervised_loss/batch: 1.2635
# 2025-11-29 11:10:30,428 - supervised_finetuning - INFO - Epoch 80 - supervised_accuracy/batch: 53.1250
# 2025-11-29 11:10:30,428 - supervised_finetuning - INFO - Epoch 80 - learning_rate: 0.0001
# Classifier Epoch 6/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.3080, Acc=37.50%]2025-11-29 11:10:30,462 - supervised_finetuning - INFO - Epoch 90 - supervised_loss/batch: 1.3080
# 2025-11-29 11:10:30,462 - supervised_finetuning - INFO - Epoch 90 - supervised_accuracy/batch: 37.5000
# 2025-11-29 11:10:30,462 - supervised_finetuning - INFO - Epoch 90 - learning_rate: 0.0001
# Classifier Epoch 6/100: 100% 16/16 [00:00<00:00, 284.11it/s, Loss=1.1618, Acc=43.64%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:30,488 - supervised_finetuning - INFO - Epoch 6:
# 2025-11-29 11:10:30,489 - supervised_finetuning - INFO -   Train Loss: 1.2662, Train Acc: 43.35%
# 2025-11-29 11:10:30,489 - supervised_finetuning - INFO -   Train F1: 28.53%, Train Recall: 43.35%
# 2025-11-29 11:10:30,489 - supervised_finetuning - INFO -   Train Precision: 25.44%
# 2025-11-29 11:10:30,489 - supervised_finetuning - INFO - Epoch 5 - supervised_loss/epoch: 1.2662
# 2025-11-29 11:10:30,489 - supervised_finetuning - INFO - Epoch 5 - supervised_accuracy/epoch: 43.3498
# 2025-11-29 11:10:30,489 - supervised_finetuning - INFO - Epoch 5 - supervised_f1/epoch: 28.5345
# 2025-11-29 11:10:30,490 - supervised_finetuning - INFO - Epoch 5 - supervised_recall/epoch: 43.3498
# 2025-11-29 11:10:30,490 - supervised_finetuning - INFO - Epoch 5 - supervised_precision/epoch: 25.4401
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:30,998 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 43.35%
# Classifier Epoch 7/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.2319, Acc=46.88%]2025-11-29 11:10:31,005 - supervised_finetuning - INFO - Epoch 96 - supervised_loss/batch: 1.2319
# 2025-11-29 11:10:31,005 - supervised_finetuning - INFO - Epoch 96 - supervised_accuracy/batch: 46.8750
# 2025-11-29 11:10:31,006 - supervised_finetuning - INFO - Epoch 96 - learning_rate: 0.0001
# Classifier Epoch 7/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.1722, Acc=42.19%]2025-11-29 11:10:31,042 - supervised_finetuning - INFO - Epoch 106 - supervised_loss/batch: 1.1722
# 2025-11-29 11:10:31,042 - supervised_finetuning - INFO - Epoch 106 - supervised_accuracy/batch: 42.1875
# 2025-11-29 11:10:31,042 - supervised_finetuning - INFO - Epoch 106 - learning_rate: 0.0001
# Classifier Epoch 7/100: 100% 16/16 [00:00<00:00, 263.51it/s, Loss=1.1631, Acc=41.82%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:31,068 - supervised_finetuning - INFO - Epoch 7:
# 2025-11-29 11:10:31,069 - supervised_finetuning - INFO -   Train Loss: 1.1953, Train Acc: 45.22%
# 2025-11-29 11:10:31,069 - supervised_finetuning - INFO -   Train F1: 33.62%, Train Recall: 45.22%
# 2025-11-29 11:10:31,069 - supervised_finetuning - INFO -   Train Precision: 27.78%
# 2025-11-29 11:10:31,069 - supervised_finetuning - INFO - Epoch 6 - supervised_loss/epoch: 1.1953
# 2025-11-29 11:10:31,069 - supervised_finetuning - INFO - Epoch 6 - supervised_accuracy/epoch: 45.2217
# 2025-11-29 11:10:31,069 - supervised_finetuning - INFO - Epoch 6 - supervised_f1/epoch: 33.6242
# 2025-11-29 11:10:31,070 - supervised_finetuning - INFO - Epoch 6 - supervised_recall/epoch: 45.2217
# 2025-11-29 11:10:31,070 - supervised_finetuning - INFO - Epoch 6 - supervised_precision/epoch: 27.7756
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:31,836 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 45.22%
# Classifier Epoch 8/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.0829, Acc=57.81%]2025-11-29 11:10:31,843 - supervised_finetuning - INFO - Epoch 112 - supervised_loss/batch: 1.0829
# 2025-11-29 11:10:31,843 - supervised_finetuning - INFO - Epoch 112 - supervised_accuracy/batch: 57.8125
# 2025-11-29 11:10:31,843 - supervised_finetuning - INFO - Epoch 112 - learning_rate: 0.0001
# Classifier Epoch 8/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.1910, Acc=46.88%]2025-11-29 11:10:31,880 - supervised_finetuning - INFO - Epoch 122 - supervised_loss/batch: 1.1910
# 2025-11-29 11:10:31,880 - supervised_finetuning - INFO - Epoch 122 - supervised_accuracy/batch: 46.8750
# 2025-11-29 11:10:31,880 - supervised_finetuning - INFO - Epoch 122 - learning_rate: 0.0001
# Classifier Epoch 8/100: 100% 16/16 [00:00<00:00, 260.56it/s, Loss=1.1708, Acc=45.45%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:31,909 - supervised_finetuning - INFO - Epoch 8:
# 2025-11-29 11:10:31,909 - supervised_finetuning - INFO -   Train Loss: 1.1407, Train Acc: 47.00%
# 2025-11-29 11:10:31,909 - supervised_finetuning - INFO -   Train F1: 37.32%, Train Recall: 47.00%
# 2025-11-29 11:10:31,909 - supervised_finetuning - INFO -   Train Precision: 30.95%
# 2025-11-29 11:10:31,909 - supervised_finetuning - INFO - Epoch 7 - supervised_loss/epoch: 1.1407
# 2025-11-29 11:10:31,910 - supervised_finetuning - INFO - Epoch 7 - supervised_accuracy/epoch: 46.9951
# 2025-11-29 11:10:31,910 - supervised_finetuning - INFO - Epoch 7 - supervised_f1/epoch: 37.3179
# 2025-11-29 11:10:31,910 - supervised_finetuning - INFO - Epoch 7 - supervised_recall/epoch: 46.9951
# 2025-11-29 11:10:31,910 - supervised_finetuning - INFO - Epoch 7 - supervised_precision/epoch: 30.9530
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:32,502 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 47.00%
# Classifier Epoch 9/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.1449, Acc=50.00%]2025-11-29 11:10:32,507 - supervised_finetuning - INFO - Epoch 128 - supervised_loss/batch: 1.1449
# 2025-11-29 11:10:32,507 - supervised_finetuning - INFO - Epoch 128 - supervised_accuracy/batch: 50.0000
# 2025-11-29 11:10:32,507 - supervised_finetuning - INFO - Epoch 128 - learning_rate: 0.0001
# Classifier Epoch 9/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.0720, Acc=46.88%]2025-11-29 11:10:32,544 - supervised_finetuning - INFO - Epoch 138 - supervised_loss/batch: 1.0720
# 2025-11-29 11:10:32,544 - supervised_finetuning - INFO - Epoch 138 - supervised_accuracy/batch: 46.8750
# 2025-11-29 11:10:32,544 - supervised_finetuning - INFO - Epoch 138 - learning_rate: 0.0001
# Classifier Epoch 9/100: 100% 16/16 [00:00<00:00, 268.68it/s, Loss=1.1226, Acc=50.91%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:10:32,571 - supervised_finetuning - INFO - Epoch 9:
# 2025-11-29 11:10:32,572 - supervised_finetuning - INFO -   Train Loss: 1.1086, Train Acc: 48.57%
# 2025-11-29 11:10:32,572 - supervised_finetuning - INFO -   Train F1: 41.64%, Train Recall: 48.57%
# 2025-11-29 11:10:32,572 - supervised_finetuning - INFO -   Train Precision: 39.71%
# 2025-11-29 11:10:32,572 - supervised_finetuning - INFO - Epoch 8 - supervised_loss/epoch: 1.1086
# 2025-11-29 11:10:32,572 - supervised_finetuning - INFO - Epoch 8 - supervised_accuracy/epoch: 48.5714
# 2025-11-29 11:10:32,572 - supervised_finetuning - INFO - Epoch 8 - supervised_f1/epoch: 41.6361
# 2025-11-29 11:10:32,573 - supervised_finetuning - INFO - Epoch 8 - supervised_recall/epoch: 48.5714
# 2025-11-29 11:10:32,573 - supervised_finetuning - INFO - Epoch 8 - supervised_precision/epoch: 39.7058
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:33,460 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 48.57%
# Classifier Epoch 10/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.0661, Acc=53.12%]2025-11-29 11:10:33,465 - supervised_finetuning - INFO - Epoch 144 - supervised_loss/batch: 1.0661
# 2025-11-29 11:10:33,465 - supervised_finetuning - INFO - Epoch 144 - supervised_accuracy/batch: 53.1250
# 2025-11-29 11:10:33,466 - supervised_finetuning - INFO - Epoch 144 - learning_rate: 0.0001
# Classifier Epoch 10/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9289, Acc=56.25%]2025-11-29 11:10:33,502 - supervised_finetuning - INFO - Epoch 154 - supervised_loss/batch: 0.9289
# 2025-11-29 11:10:33,503 - supervised_finetuning - INFO - Epoch 154 - supervised_accuracy/batch: 56.2500
# 2025-11-29 11:10:33,503 - supervised_finetuning - INFO - Epoch 154 - learning_rate: 0.0001
# Classifier Epoch 10/100: 100% 16/16 [00:00<00:00, 266.51it/s, Loss=1.1574, Acc=50.91%]
# 2025-11-29 11:10:33,530 - supervised_finetuning - INFO - Epoch 10:
# 2025-11-29 11:10:33,530 - supervised_finetuning - INFO -   Train Loss: 1.0863, Train Acc: 52.51%
# 2025-11-29 11:10:33,530 - supervised_finetuning - INFO -   Train F1: 47.25%, Train Recall: 52.51%
# 2025-11-29 11:10:33,530 - supervised_finetuning - INFO -   Train Precision: 54.76%
# 2025-11-29 11:10:33,531 - supervised_finetuning - INFO - Epoch 9 - supervised_loss/epoch: 1.0863
# 2025-11-29 11:10:33,531 - supervised_finetuning - INFO - Epoch 9 - supervised_accuracy/epoch: 52.5123
# 2025-11-29 11:10:33,531 - supervised_finetuning - INFO - Epoch 9 - supervised_f1/epoch: 47.2452
# 2025-11-29 11:10:33,531 - supervised_finetuning - INFO - Epoch 9 - supervised_recall/epoch: 52.5123
# 2025-11-29 11:10:33,531 - supervised_finetuning - INFO - Epoch 9 - supervised_precision/epoch: 54.7604
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:34,468 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 52.51%
# Classifier Epoch 11/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.1356, Acc=45.31%]2025-11-29 11:10:34,475 - supervised_finetuning - INFO - Epoch 160 - supervised_loss/batch: 1.1356
# 2025-11-29 11:10:34,475 - supervised_finetuning - INFO - Epoch 160 - supervised_accuracy/batch: 45.3125
# 2025-11-29 11:10:34,475 - supervised_finetuning - INFO - Epoch 160 - learning_rate: 0.0001
# Classifier Epoch 11/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.1478, Acc=48.44%]2025-11-29 11:10:34,519 - supervised_finetuning - INFO - Epoch 170 - supervised_loss/batch: 1.1478
# 2025-11-29 11:10:34,519 - supervised_finetuning - INFO - Epoch 170 - supervised_accuracy/batch: 48.4375
# 2025-11-29 11:10:34,520 - supervised_finetuning - INFO - Epoch 170 - learning_rate: 0.0001
# Classifier Epoch 11/100: 100% 16/16 [00:00<00:00, 220.41it/s, Loss=0.9785, Acc=54.55%]
# 2025-11-29 11:10:34,552 - supervised_finetuning - INFO - Epoch 11:
# 2025-11-29 11:10:34,552 - supervised_finetuning - INFO -   Train Loss: 1.0637, Train Acc: 52.81%
# 2025-11-29 11:10:34,552 - supervised_finetuning - INFO -   Train F1: 49.88%, Train Recall: 52.81%
# 2025-11-29 11:10:34,552 - supervised_finetuning - INFO -   Train Precision: 49.76%
# 2025-11-29 11:10:34,552 - supervised_finetuning - INFO - Epoch 10 - supervised_loss/epoch: 1.0637
# 2025-11-29 11:10:34,552 - supervised_finetuning - INFO - Epoch 10 - supervised_accuracy/epoch: 52.8079
# 2025-11-29 11:10:34,552 - supervised_finetuning - INFO - Epoch 10 - supervised_f1/epoch: 49.8815
# 2025-11-29 11:10:34,553 - supervised_finetuning - INFO - Epoch 10 - supervised_recall/epoch: 52.8079
# 2025-11-29 11:10:34,553 - supervised_finetuning - INFO - Epoch 10 - supervised_precision/epoch: 49.7568
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:34,994 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 52.81%
# Classifier Epoch 12/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9528, Acc=57.81%]2025-11-29 11:10:35,004 - supervised_finetuning - INFO - Epoch 176 - supervised_loss/batch: 0.9528
# 2025-11-29 11:10:35,004 - supervised_finetuning - INFO - Epoch 176 - supervised_accuracy/batch: 57.8125
# 2025-11-29 11:10:35,004 - supervised_finetuning - INFO - Epoch 176 - learning_rate: 0.0001
# Classifier Epoch 12/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.0281, Acc=62.50%]2025-11-29 11:10:35,048 - supervised_finetuning - INFO - Epoch 186 - supervised_loss/batch: 1.0281
# 2025-11-29 11:10:35,048 - supervised_finetuning - INFO - Epoch 186 - supervised_accuracy/batch: 62.5000
# 2025-11-29 11:10:35,048 - supervised_finetuning - INFO - Epoch 186 - learning_rate: 0.0001
# Classifier Epoch 12/100: 100% 16/16 [00:00<00:00, 223.02it/s, Loss=1.0276, Acc=60.00%]
# 2025-11-29 11:10:35,075 - supervised_finetuning - INFO - Epoch 12:
# 2025-11-29 11:10:35,075 - supervised_finetuning - INFO -   Train Loss: 1.0428, Train Acc: 55.17%
# 2025-11-29 11:10:35,075 - supervised_finetuning - INFO -   Train F1: 52.76%, Train Recall: 55.17%
# 2025-11-29 11:10:35,076 - supervised_finetuning - INFO -   Train Precision: 53.15%
# 2025-11-29 11:10:35,076 - supervised_finetuning - INFO - Epoch 11 - supervised_loss/epoch: 1.0428
# 2025-11-29 11:10:35,076 - supervised_finetuning - INFO - Epoch 11 - supervised_accuracy/epoch: 55.1724
# 2025-11-29 11:10:35,076 - supervised_finetuning - INFO - Epoch 11 - supervised_f1/epoch: 52.7555
# 2025-11-29 11:10:35,076 - supervised_finetuning - INFO - Epoch 11 - supervised_recall/epoch: 55.1724
# 2025-11-29 11:10:35,077 - supervised_finetuning - INFO - Epoch 11 - supervised_precision/epoch: 53.1483
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:35,822 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 55.17%
# Classifier Epoch 13/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.0919, Acc=50.00%]2025-11-29 11:10:35,827 - supervised_finetuning - INFO - Epoch 192 - supervised_loss/batch: 1.0919
# 2025-11-29 11:10:35,828 - supervised_finetuning - INFO - Epoch 192 - supervised_accuracy/batch: 50.0000
# 2025-11-29 11:10:35,828 - supervised_finetuning - INFO - Epoch 192 - learning_rate: 0.0001
# Classifier Epoch 13/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.1090, Acc=46.88%]2025-11-29 11:10:35,866 - supervised_finetuning - INFO - Epoch 202 - supervised_loss/batch: 1.1090
# 2025-11-29 11:10:35,866 - supervised_finetuning - INFO - Epoch 202 - supervised_accuracy/batch: 46.8750
# 2025-11-29 11:10:35,867 - supervised_finetuning - INFO - Epoch 202 - learning_rate: 0.0001
# Classifier Epoch 13/100: 100% 16/16 [00:00<00:00, 231.20it/s, Loss=0.9924, Acc=56.36%]
# 2025-11-29 11:10:35,901 - supervised_finetuning - INFO - Epoch 13:
# 2025-11-29 11:10:35,901 - supervised_finetuning - INFO -   Train Loss: 1.0232, Train Acc: 54.98%
# 2025-11-29 11:10:35,901 - supervised_finetuning - INFO -   Train F1: 52.48%, Train Recall: 54.98%
# 2025-11-29 11:10:35,902 - supervised_finetuning - INFO -   Train Precision: 52.19%
# 2025-11-29 11:10:35,902 - supervised_finetuning - INFO - Epoch 12 - supervised_loss/epoch: 1.0232
# 2025-11-29 11:10:35,902 - supervised_finetuning - INFO - Epoch 12 - supervised_accuracy/epoch: 54.9754
# 2025-11-29 11:10:35,902 - supervised_finetuning - INFO - Epoch 12 - supervised_f1/epoch: 52.4803
# 2025-11-29 11:10:35,902 - supervised_finetuning - INFO - Epoch 12 - supervised_recall/epoch: 54.9754
# 2025-11-29 11:10:35,903 - supervised_finetuning - INFO - Epoch 12 - supervised_precision/epoch: 52.1854
# Classifier Epoch 14/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.0056, Acc=57.81%]2025-11-29 11:10:35,907 - supervised_finetuning - INFO - Epoch 208 - supervised_loss/batch: 1.0056
# 2025-11-29 11:10:35,907 - supervised_finetuning - INFO - Epoch 208 - supervised_accuracy/batch: 57.8125
# 2025-11-29 11:10:35,908 - supervised_finetuning - INFO - Epoch 208 - learning_rate: 0.0001
# Classifier Epoch 14/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9724, Acc=60.94%]2025-11-29 11:10:35,946 - supervised_finetuning - INFO - Epoch 218 - supervised_loss/batch: 0.9724
# 2025-11-29 11:10:35,946 - supervised_finetuning - INFO - Epoch 218 - supervised_accuracy/batch: 60.9375
# 2025-11-29 11:10:35,947 - supervised_finetuning - INFO - Epoch 218 - learning_rate: 0.0001
# Classifier Epoch 14/100: 100% 16/16 [00:00<00:00, 258.84it/s, Loss=0.8807, Acc=61.82%]
# 2025-11-29 11:10:35,973 - supervised_finetuning - INFO - Epoch 14:
# 2025-11-29 11:10:35,974 - supervised_finetuning - INFO -   Train Loss: 1.0042, Train Acc: 57.04%
# 2025-11-29 11:10:35,974 - supervised_finetuning - INFO -   Train F1: 53.36%, Train Recall: 57.04%
# 2025-11-29 11:10:35,974 - supervised_finetuning - INFO -   Train Precision: 54.58%
# 2025-11-29 11:10:35,974 - supervised_finetuning - INFO - Epoch 13 - supervised_loss/epoch: 1.0042
# 2025-11-29 11:10:35,974 - supervised_finetuning - INFO - Epoch 13 - supervised_accuracy/epoch: 57.0443
# 2025-11-29 11:10:35,974 - supervised_finetuning - INFO - Epoch 13 - supervised_f1/epoch: 53.3559
# 2025-11-29 11:10:35,975 - supervised_finetuning - INFO - Epoch 13 - supervised_recall/epoch: 57.0443
# 2025-11-29 11:10:35,975 - supervised_finetuning - INFO - Epoch 13 - supervised_precision/epoch: 54.5764
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:38,626 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 57.04%
# Classifier Epoch 15/100:   0% 0/16 [00:00<?, ?it/s, Loss=1.1452, Acc=45.31%]2025-11-29 11:10:38,633 - supervised_finetuning - INFO - Epoch 224 - supervised_loss/batch: 1.1452
# 2025-11-29 11:10:38,633 - supervised_finetuning - INFO - Epoch 224 - supervised_accuracy/batch: 45.3125
# 2025-11-29 11:10:38,633 - supervised_finetuning - INFO - Epoch 224 - learning_rate: 0.0001
# Classifier Epoch 15/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9347, Acc=56.25%]2025-11-29 11:10:38,680 - supervised_finetuning - INFO - Epoch 234 - supervised_loss/batch: 0.9347
# 2025-11-29 11:10:38,680 - supervised_finetuning - INFO - Epoch 234 - supervised_accuracy/batch: 56.2500
# 2025-11-29 11:10:38,680 - supervised_finetuning - INFO - Epoch 234 - learning_rate: 0.0001
# Classifier Epoch 15/100: 100% 16/16 [00:00<00:00, 198.98it/s, Loss=1.0864, Acc=47.27%]
# 2025-11-29 11:10:38,723 - supervised_finetuning - INFO - Epoch 15:
# 2025-11-29 11:10:38,723 - supervised_finetuning - INFO -   Train Loss: 0.9938, Train Acc: 56.55%
# 2025-11-29 11:10:38,723 - supervised_finetuning - INFO -   Train F1: 52.32%, Train Recall: 56.55%
# 2025-11-29 11:10:38,723 - supervised_finetuning - INFO -   Train Precision: 52.86%
# 2025-11-29 11:10:38,723 - supervised_finetuning - INFO - Epoch 14 - supervised_loss/epoch: 0.9938
# 2025-11-29 11:10:38,723 - supervised_finetuning - INFO - Epoch 14 - supervised_accuracy/epoch: 56.5517
# 2025-11-29 11:10:38,723 - supervised_finetuning - INFO - Epoch 14 - supervised_f1/epoch: 52.3226
# 2025-11-29 11:10:38,724 - supervised_finetuning - INFO - Epoch 14 - supervised_recall/epoch: 56.5517
# 2025-11-29 11:10:38,724 - supervised_finetuning - INFO - Epoch 14 - supervised_precision/epoch: 52.8600
# Classifier Epoch 16/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9719, Acc=56.25%]2025-11-29 11:10:38,732 - supervised_finetuning - INFO - Epoch 240 - supervised_loss/batch: 0.9719
# 2025-11-29 11:10:38,732 - supervised_finetuning - INFO - Epoch 240 - supervised_accuracy/batch: 56.2500
# 2025-11-29 11:10:38,732 - supervised_finetuning - INFO - Epoch 240 - learning_rate: 0.0001
# Classifier Epoch 16/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7978, Acc=67.19%]2025-11-29 11:10:38,784 - supervised_finetuning - INFO - Epoch 250 - supervised_loss/batch: 0.7978
# 2025-11-29 11:10:38,785 - supervised_finetuning - INFO - Epoch 250 - supervised_accuracy/batch: 67.1875
# 2025-11-29 11:10:38,785 - supervised_finetuning - INFO - Epoch 250 - learning_rate: 0.0001
# Classifier Epoch 16/100: 100% 16/16 [00:00<00:00, 179.29it/s, Loss=1.0114, Acc=58.18%]
# 2025-11-29 11:10:38,829 - supervised_finetuning - INFO - Epoch 16:
# 2025-11-29 11:10:38,829 - supervised_finetuning - INFO -   Train Loss: 0.9692, Train Acc: 57.93%
# 2025-11-29 11:10:38,829 - supervised_finetuning - INFO -   Train F1: 53.47%, Train Recall: 57.93%
# 2025-11-29 11:10:38,830 - supervised_finetuning - INFO -   Train Precision: 54.73%
# 2025-11-29 11:10:38,830 - supervised_finetuning - INFO - Epoch 15 - supervised_loss/epoch: 0.9692
# 2025-11-29 11:10:38,830 - supervised_finetuning - INFO - Epoch 15 - supervised_accuracy/epoch: 57.9310
# 2025-11-29 11:10:38,830 - supervised_finetuning - INFO - Epoch 15 - supervised_f1/epoch: 53.4711
# 2025-11-29 11:10:38,830 - supervised_finetuning - INFO - Epoch 15 - supervised_recall/epoch: 57.9310
# 2025-11-29 11:10:38,831 - supervised_finetuning - INFO - Epoch 15 - supervised_precision/epoch: 54.7281
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:39,373 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 57.93%
# Classifier Epoch 17/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9800, Acc=54.69%]2025-11-29 11:10:39,379 - supervised_finetuning - INFO - Epoch 256 - supervised_loss/batch: 0.9800
# 2025-11-29 11:10:39,379 - supervised_finetuning - INFO - Epoch 256 - supervised_accuracy/batch: 54.6875
# 2025-11-29 11:10:39,379 - supervised_finetuning - INFO - Epoch 256 - learning_rate: 0.0001
# Classifier Epoch 17/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9729, Acc=59.38%]2025-11-29 11:10:39,416 - supervised_finetuning - INFO - Epoch 266 - supervised_loss/batch: 0.9729
# 2025-11-29 11:10:39,416 - supervised_finetuning - INFO - Epoch 266 - supervised_accuracy/batch: 59.3750
# 2025-11-29 11:10:39,416 - supervised_finetuning - INFO - Epoch 266 - learning_rate: 0.0001
# Classifier Epoch 17/100: 100% 16/16 [00:00<00:00, 265.90it/s, Loss=0.8395, Acc=65.45%]
# 2025-11-29 11:10:39,443 - supervised_finetuning - INFO - Epoch 17:
# 2025-11-29 11:10:39,443 - supervised_finetuning - INFO -   Train Loss: 0.9637, Train Acc: 57.14%
# 2025-11-29 11:10:39,443 - supervised_finetuning - INFO -   Train F1: 54.24%, Train Recall: 57.14%
# 2025-11-29 11:10:39,443 - supervised_finetuning - INFO -   Train Precision: 53.83%
# 2025-11-29 11:10:39,443 - supervised_finetuning - INFO - Epoch 16 - supervised_loss/epoch: 0.9637
# 2025-11-29 11:10:39,444 - supervised_finetuning - INFO - Epoch 16 - supervised_accuracy/epoch: 57.1429
# 2025-11-29 11:10:39,444 - supervised_finetuning - INFO - Epoch 16 - supervised_f1/epoch: 54.2385
# 2025-11-29 11:10:39,444 - supervised_finetuning - INFO - Epoch 16 - supervised_recall/epoch: 57.1429
# 2025-11-29 11:10:39,444 - supervised_finetuning - INFO - Epoch 16 - supervised_precision/epoch: 53.8307
# Classifier Epoch 18/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9589, Acc=60.94%]2025-11-29 11:10:39,449 - supervised_finetuning - INFO - Epoch 272 - supervised_loss/batch: 0.9589
# 2025-11-29 11:10:39,449 - supervised_finetuning - INFO - Epoch 272 - supervised_accuracy/batch: 60.9375
# 2025-11-29 11:10:39,449 - supervised_finetuning - INFO - Epoch 272 - learning_rate: 0.0001
# Classifier Epoch 18/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9840, Acc=64.06%]2025-11-29 11:10:39,493 - supervised_finetuning - INFO - Epoch 282 - supervised_loss/batch: 0.9840
# 2025-11-29 11:10:39,493 - supervised_finetuning - INFO - Epoch 282 - supervised_accuracy/batch: 64.0625
# 2025-11-29 11:10:39,494 - supervised_finetuning - INFO - Epoch 282 - learning_rate: 0.0001
# Classifier Epoch 18/100: 100% 16/16 [00:00<00:00, 237.55it/s, Loss=1.0192, Acc=54.55%]
# 2025-11-29 11:10:39,520 - supervised_finetuning - INFO - Epoch 18:
# 2025-11-29 11:10:39,520 - supervised_finetuning - INFO -   Train Loss: 0.9447, Train Acc: 58.72%
# 2025-11-29 11:10:39,521 - supervised_finetuning - INFO -   Train F1: 55.68%, Train Recall: 58.72%
# 2025-11-29 11:10:39,521 - supervised_finetuning - INFO -   Train Precision: 56.11%
# 2025-11-29 11:10:39,521 - supervised_finetuning - INFO - Epoch 17 - supervised_loss/epoch: 0.9447
# 2025-11-29 11:10:39,521 - supervised_finetuning - INFO - Epoch 17 - supervised_accuracy/epoch: 58.7192
# 2025-11-29 11:10:39,521 - supervised_finetuning - INFO - Epoch 17 - supervised_f1/epoch: 55.6800
# 2025-11-29 11:10:39,521 - supervised_finetuning - INFO - Epoch 17 - supervised_recall/epoch: 58.7192
# 2025-11-29 11:10:39,522 - supervised_finetuning - INFO - Epoch 17 - supervised_precision/epoch: 56.1100
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:40,141 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 58.72%
# Classifier Epoch 19/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.8981, Acc=57.81%]2025-11-29 11:10:40,146 - supervised_finetuning - INFO - Epoch 288 - supervised_loss/batch: 0.8981
# 2025-11-29 11:10:40,147 - supervised_finetuning - INFO - Epoch 288 - supervised_accuracy/batch: 57.8125
# 2025-11-29 11:10:40,147 - supervised_finetuning - INFO - Epoch 288 - learning_rate: 0.0001
# Classifier Epoch 19/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.8838, Acc=62.50%]2025-11-29 11:10:40,185 - supervised_finetuning - INFO - Epoch 298 - supervised_loss/batch: 0.8838
# 2025-11-29 11:10:40,185 - supervised_finetuning - INFO - Epoch 298 - supervised_accuracy/batch: 62.5000
# 2025-11-29 11:10:40,185 - supervised_finetuning - INFO - Epoch 298 - learning_rate: 0.0001
# Classifier Epoch 19/100: 100% 16/16 [00:00<00:00, 260.95it/s, Loss=0.9189, Acc=60.00%]
# 2025-11-29 11:10:40,213 - supervised_finetuning - INFO - Epoch 19:
# 2025-11-29 11:10:40,214 - supervised_finetuning - INFO -   Train Loss: 0.9401, Train Acc: 59.11%
# 2025-11-29 11:10:40,214 - supervised_finetuning - INFO -   Train F1: 56.50%, Train Recall: 59.11%
# 2025-11-29 11:10:40,214 - supervised_finetuning - INFO -   Train Precision: 56.46%
# 2025-11-29 11:10:40,214 - supervised_finetuning - INFO - Epoch 18 - supervised_loss/epoch: 0.9401
# 2025-11-29 11:10:40,214 - supervised_finetuning - INFO - Epoch 18 - supervised_accuracy/epoch: 59.1133
# 2025-11-29 11:10:40,214 - supervised_finetuning - INFO - Epoch 18 - supervised_f1/epoch: 56.4978
# 2025-11-29 11:10:40,214 - supervised_finetuning - INFO - Epoch 18 - supervised_recall/epoch: 59.1133
# 2025-11-29 11:10:40,215 - supervised_finetuning - INFO - Epoch 18 - supervised_precision/epoch: 56.4574
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:10:42,772 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 59.11%
# Classifier Epoch 20/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.8266, Acc=67.19%]2025-11-29 11:10:42,777 - supervised_finetuning - INFO - Epoch 304 - supervised_loss/batch: 0.8266
# 2025-11-29 11:10:42,777 - supervised_finetuning - INFO - Epoch 304 - supervised_accuracy/batch: 67.1875
# 2025-11-29 11:10:42,777 - supervised_finetuning - INFO - Epoch 304 - learning_rate: 0.0001
# Classifier Epoch 20/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.9022, Acc=53.12%]2025-11-29 11:10:42,812 - supervised_finetuning - INFO - Epoch 314 - supervised_loss/batch: 0.9022
# 2025-11-29 11:10:42,812 - supervised_finetuning - INFO - Epoch 314 - supervised_accuracy/batch: 53.1250
# 2025-11-29 11:10:42,812 - supervised_finetuning - INFO - Epoch 314 - learning_rate: 0.0001
# Classifier Epoch 20/100: 100% 16/16 [00:00<00:00, 274.62it/s, Loss=0.8713, Acc=61.82%]
# ...
# 2025-11-29 11:11:11,364 - supervised_finetuning - INFO - Epoch 90 - supervised_precision/epoch: 74.0655
# Classifier Epoch 92/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.5620, Acc=81.25%]2025-11-29 11:11:11,369 - supervised_finetuning - INFO - Epoch 1456 - supervised_loss/batch: 0.5620
# 2025-11-29 11:11:11,369 - supervised_finetuning - INFO - Epoch 1456 - supervised_accuracy/batch: 81.2500
# 2025-11-29 11:11:11,369 - supervised_finetuning - INFO - Epoch 1456 - learning_rate: 0.0001
# Classifier Epoch 92/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.5924, Acc=73.44%]2025-11-29 11:11:11,407 - supervised_finetuning - INFO - Epoch 1466 - supervised_loss/batch: 0.5924
# 2025-11-29 11:11:11,407 - supervised_finetuning - INFO - Epoch 1466 - supervised_accuracy/batch: 73.4375
# 2025-11-29 11:11:11,407 - supervised_finetuning - INFO - Epoch 1466 - learning_rate: 0.0001
# Classifier Epoch 92/100: 100% 16/16 [00:00<00:00, 239.82it/s, Loss=0.7542, Acc=63.64%]
# 2025-11-29 11:11:11,447 - supervised_finetuning - INFO - Epoch 92:
# 2025-11-29 11:11:11,447 - supervised_finetuning - INFO -   Train Loss: 0.6500, Train Acc: 73.00%
# 2025-11-29 11:11:11,447 - supervised_finetuning - INFO -   Train F1: 73.43%, Train Recall: 73.00%
# 2025-11-29 11:11:11,447 - supervised_finetuning - INFO -   Train Precision: 74.75%
# 2025-11-29 11:11:11,447 - supervised_finetuning - INFO - Epoch 91 - supervised_loss/epoch: 0.6500
# 2025-11-29 11:11:11,447 - supervised_finetuning - INFO - Epoch 91 - supervised_accuracy/epoch: 73.0049
# 2025-11-29 11:11:11,447 - supervised_finetuning - INFO - Epoch 91 - supervised_f1/epoch: 73.4279
# 2025-11-29 11:11:11,448 - supervised_finetuning - INFO - Epoch 91 - supervised_recall/epoch: 73.0049
# 2025-11-29 11:11:11,448 - supervised_finetuning - INFO - Epoch 91 - supervised_precision/epoch: 74.7544
# Classifier Epoch 93/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.5095, Acc=79.69%]2025-11-29 11:11:11,452 - supervised_finetuning - INFO - Epoch 1472 - supervised_loss/batch: 0.5095
# 2025-11-29 11:11:11,452 - supervised_finetuning - INFO - Epoch 1472 - supervised_accuracy/batch: 79.6875
# 2025-11-29 11:11:11,453 - supervised_finetuning - INFO - Epoch 1472 - learning_rate: 0.0001
# Classifier Epoch 93/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.5847, Acc=79.69%]2025-11-29 11:11:11,491 - supervised_finetuning - INFO - Epoch 1482 - supervised_loss/batch: 0.5847
# 2025-11-29 11:11:11,492 - supervised_finetuning - INFO - Epoch 1482 - supervised_accuracy/batch: 79.6875
# 2025-11-29 11:11:11,492 - supervised_finetuning - INFO - Epoch 1482 - learning_rate: 0.0001
# Classifier Epoch 93/100: 100% 16/16 [00:00<00:00, 242.70it/s, Loss=0.6409, Acc=69.09%]
# 2025-11-29 11:11:11,529 - supervised_finetuning - INFO - Epoch 93:
# 2025-11-29 11:11:11,529 - supervised_finetuning - INFO -   Train Loss: 0.6511, Train Acc: 73.20%
# 2025-11-29 11:11:11,529 - supervised_finetuning - INFO -   Train F1: 73.35%, Train Recall: 73.20%
# 2025-11-29 11:11:11,529 - supervised_finetuning - INFO -   Train Precision: 74.22%
# 2025-11-29 11:11:11,529 - supervised_finetuning - INFO - Epoch 92 - supervised_loss/epoch: 0.6511
# 2025-11-29 11:11:11,529 - supervised_finetuning - INFO - Epoch 92 - supervised_accuracy/epoch: 73.2020
# 2025-11-29 11:11:11,529 - supervised_finetuning - INFO - Epoch 92 - supervised_f1/epoch: 73.3484
# 2025-11-29 11:11:11,530 - supervised_finetuning - INFO - Epoch 92 - supervised_recall/epoch: 73.2020
# 2025-11-29 11:11:11,530 - supervised_finetuning - INFO - Epoch 92 - supervised_precision/epoch: 74.2160
# Classifier Epoch 94/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.4437, Acc=84.38%]2025-11-29 11:11:11,535 - supervised_finetuning - INFO - Epoch 1488 - supervised_loss/batch: 0.4437
# 2025-11-29 11:11:11,535 - supervised_finetuning - INFO - Epoch 1488 - supervised_accuracy/batch: 84.3750
# 2025-11-29 11:11:11,535 - supervised_finetuning - INFO - Epoch 1488 - learning_rate: 0.0001
# Classifier Epoch 94/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7322, Acc=71.88%]2025-11-29 11:11:11,574 - supervised_finetuning - INFO - Epoch 1498 - supervised_loss/batch: 0.7322
# 2025-11-29 11:11:11,574 - supervised_finetuning - INFO - Epoch 1498 - supervised_accuracy/batch: 71.8750
# 2025-11-29 11:11:11,574 - supervised_finetuning - INFO - Epoch 1498 - learning_rate: 0.0001
# Classifier Epoch 94/100: 100% 16/16 [00:00<00:00, 256.42it/s, Loss=0.6796, Acc=70.91%]
# 2025-11-29 11:11:11,603 - supervised_finetuning - INFO - Epoch 94:
# 2025-11-29 11:11:11,603 - supervised_finetuning - INFO -   Train Loss: 0.6389, Train Acc: 73.60%
# 2025-11-29 11:11:11,603 - supervised_finetuning - INFO -   Train F1: 73.86%, Train Recall: 73.60%
# 2025-11-29 11:11:11,603 - supervised_finetuning - INFO -   Train Precision: 74.88%
# 2025-11-29 11:11:11,603 - supervised_finetuning - INFO - Epoch 93 - supervised_loss/epoch: 0.6389
# 2025-11-29 11:11:11,603 - supervised_finetuning - INFO - Epoch 93 - supervised_accuracy/epoch: 73.5961
# 2025-11-29 11:11:11,604 - supervised_finetuning - INFO - Epoch 93 - supervised_f1/epoch: 73.8627
# 2025-11-29 11:11:11,604 - supervised_finetuning - INFO - Epoch 93 - supervised_recall/epoch: 73.5961
# 2025-11-29 11:11:11,604 - supervised_finetuning - INFO - Epoch 93 - supervised_precision/epoch: 74.8752
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:11:12,139 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 73.60%
# Classifier Epoch 95/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7174, Acc=71.88%]2025-11-29 11:11:12,145 - supervised_finetuning - INFO - Epoch 1504 - supervised_loss/batch: 0.7174
# 2025-11-29 11:11:12,145 - supervised_finetuning - INFO - Epoch 1504 - supervised_accuracy/batch: 71.8750
# 2025-11-29 11:11:12,145 - supervised_finetuning - INFO - Epoch 1504 - learning_rate: 0.0001
# Classifier Epoch 95/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.5251, Acc=82.81%]2025-11-29 11:11:12,183 - supervised_finetuning - INFO - Epoch 1514 - supervised_loss/batch: 0.5251
# 2025-11-29 11:11:12,183 - supervised_finetuning - INFO - Epoch 1514 - supervised_accuracy/batch: 82.8125
# 2025-11-29 11:11:12,183 - supervised_finetuning - INFO - Epoch 1514 - learning_rate: 0.0001
# Classifier Epoch 95/100: 100% 16/16 [00:00<00:00, 254.47it/s, Loss=0.7429, Acc=67.27%]
# 2025-11-29 11:11:12,212 - supervised_finetuning - INFO - Epoch 95:
# 2025-11-29 11:11:12,212 - supervised_finetuning - INFO -   Train Loss: 0.6428, Train Acc: 74.09%
# 2025-11-29 11:11:12,212 - supervised_finetuning - INFO -   Train F1: 74.18%, Train Recall: 74.09%
# 2025-11-29 11:11:12,213 - supervised_finetuning - INFO -   Train Precision: 74.81%
# 2025-11-29 11:11:12,213 - supervised_finetuning - INFO - Epoch 94 - supervised_loss/epoch: 0.6428
# 2025-11-29 11:11:12,213 - supervised_finetuning - INFO - Epoch 94 - supervised_accuracy/epoch: 74.0887
# 2025-11-29 11:11:12,213 - supervised_finetuning - INFO - Epoch 94 - supervised_f1/epoch: 74.1799
# 2025-11-29 11:11:12,213 - supervised_finetuning - INFO - Epoch 94 - supervised_recall/epoch: 74.0887
# 2025-11-29 11:11:12,213 - supervised_finetuning - INFO - Epoch 94 - supervised_precision/epoch: 74.8082
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:11:12,986 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 74.09%
# Classifier Epoch 96/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7072, Acc=70.31%]2025-11-29 11:11:12,991 - supervised_finetuning - INFO - Epoch 1520 - supervised_loss/batch: 0.7072
# 2025-11-29 11:11:12,992 - supervised_finetuning - INFO - Epoch 1520 - supervised_accuracy/batch: 70.3125
# 2025-11-29 11:11:12,992 - supervised_finetuning - INFO - Epoch 1520 - learning_rate: 0.0001
# Classifier Epoch 96/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7488, Acc=60.94%]2025-11-29 11:11:13,029 - supervised_finetuning - INFO - Epoch 1530 - supervised_loss/batch: 0.7488
# 2025-11-29 11:11:13,029 - supervised_finetuning - INFO - Epoch 1530 - supervised_accuracy/batch: 60.9375
# 2025-11-29 11:11:13,030 - supervised_finetuning - INFO - Epoch 1530 - learning_rate: 0.0001
# Classifier Epoch 96/100: 100% 16/16 [00:00<00:00, 212.30it/s, Loss=0.5532, Acc=72.73%]
# 2025-11-29 11:11:13,071 - supervised_finetuning - INFO - Epoch 96:
# 2025-11-29 11:11:13,071 - supervised_finetuning - INFO -   Train Loss: 0.6442, Train Acc: 72.91%
# 2025-11-29 11:11:13,071 - supervised_finetuning - INFO -   Train F1: 73.27%, Train Recall: 72.91%
# 2025-11-29 11:11:13,072 - supervised_finetuning - INFO -   Train Precision: 74.42%
# 2025-11-29 11:11:13,072 - supervised_finetuning - INFO - Epoch 95 - supervised_loss/epoch: 0.6442
# 2025-11-29 11:11:13,072 - supervised_finetuning - INFO - Epoch 95 - supervised_accuracy/epoch: 72.9064
# 2025-11-29 11:11:13,072 - supervised_finetuning - INFO - Epoch 95 - supervised_f1/epoch: 73.2722
# 2025-11-29 11:11:13,072 - supervised_finetuning - INFO - Epoch 95 - supervised_recall/epoch: 72.9064
# 2025-11-29 11:11:13,072 - supervised_finetuning - INFO - Epoch 95 - supervised_precision/epoch: 74.4249
# Classifier Epoch 97/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7074, Acc=75.00%]2025-11-29 11:11:13,077 - supervised_finetuning - INFO - Epoch 1536 - supervised_loss/batch: 0.7074
# 2025-11-29 11:11:13,077 - supervised_finetuning - INFO - Epoch 1536 - supervised_accuracy/batch: 75.0000
# 2025-11-29 11:11:13,078 - supervised_finetuning - INFO - Epoch 1536 - learning_rate: 0.0001
# Classifier Epoch 97/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.6716, Acc=76.56%]2025-11-29 11:11:13,116 - supervised_finetuning - INFO - Epoch 1546 - supervised_loss/batch: 0.6716
# 2025-11-29 11:11:13,117 - supervised_finetuning - INFO - Epoch 1546 - supervised_accuracy/batch: 76.5625
# 2025-11-29 11:11:13,117 - supervised_finetuning - INFO - Epoch 1546 - learning_rate: 0.0001
# Classifier Epoch 97/100: 100% 16/16 [00:00<00:00, 254.93it/s, Loss=0.5633, Acc=80.00%]
# 2025-11-29 11:11:13,144 - supervised_finetuning - INFO - Epoch 97:
# 2025-11-29 11:11:13,144 - supervised_finetuning - INFO -   Train Loss: 0.6385, Train Acc: 72.91%
# 2025-11-29 11:11:13,144 - supervised_finetuning - INFO -   Train F1: 73.02%, Train Recall: 72.91%
# 2025-11-29 11:11:13,144 - supervised_finetuning - INFO -   Train Precision: 73.75%
# 2025-11-29 11:11:13,145 - supervised_finetuning - INFO - Epoch 96 - supervised_loss/epoch: 0.6385
# 2025-11-29 11:11:13,145 - supervised_finetuning - INFO - Epoch 96 - supervised_accuracy/epoch: 72.9064
# 2025-11-29 11:11:13,145 - supervised_finetuning - INFO - Epoch 96 - supervised_f1/epoch: 73.0181
# 2025-11-29 11:11:13,145 - supervised_finetuning - INFO - Epoch 96 - supervised_recall/epoch: 72.9064
# 2025-11-29 11:11:13,145 - supervised_finetuning - INFO - Epoch 96 - supervised_precision/epoch: 73.7527
# Classifier Epoch 98/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.6325, Acc=75.00%]2025-11-29 11:11:13,150 - supervised_finetuning - INFO - Epoch 1552 - supervised_loss/batch: 0.6325
# 2025-11-29 11:11:13,150 - supervised_finetuning - INFO - Epoch 1552 - supervised_accuracy/batch: 75.0000
# 2025-11-29 11:11:13,150 - supervised_finetuning - INFO - Epoch 1552 - learning_rate: 0.0001
# Classifier Epoch 98/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.5544, Acc=81.25%]2025-11-29 11:11:13,191 - supervised_finetuning - INFO - Epoch 1562 - supervised_loss/batch: 0.5544
# 2025-11-29 11:11:13,191 - supervised_finetuning - INFO - Epoch 1562 - supervised_accuracy/batch: 81.2500
# 2025-11-29 11:11:13,191 - supervised_finetuning - INFO - Epoch 1562 - learning_rate: 0.0001
# Classifier Epoch 98/100: 100% 16/16 [00:00<00:00, 249.49it/s, Loss=0.6087, Acc=78.18%]
# 2025-11-29 11:11:13,221 - supervised_finetuning - INFO - Epoch 98:
# 2025-11-29 11:11:13,221 - supervised_finetuning - INFO -   Train Loss: 0.6348, Train Acc: 74.09%
# 2025-11-29 11:11:13,222 - supervised_finetuning - INFO -   Train F1: 74.29%, Train Recall: 74.09%
# 2025-11-29 11:11:13,222 - supervised_finetuning - INFO -   Train Precision: 75.05%
# 2025-11-29 11:11:13,222 - supervised_finetuning - INFO - Epoch 97 - supervised_loss/epoch: 0.6348
# 2025-11-29 11:11:13,222 - supervised_finetuning - INFO - Epoch 97 - supervised_accuracy/epoch: 74.0887
# 2025-11-29 11:11:13,222 - supervised_finetuning - INFO - Epoch 97 - supervised_f1/epoch: 74.2853
# 2025-11-29 11:11:13,222 - supervised_finetuning - INFO - Epoch 97 - supervised_recall/epoch: 74.0887
# 2025-11-29 11:11:13,223 - supervised_finetuning - INFO - Epoch 97 - supervised_precision/epoch: 75.0544
# Classifier Epoch 99/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.5712, Acc=79.69%]2025-11-29 11:11:13,228 - supervised_finetuning - INFO - Epoch 1568 - supervised_loss/batch: 0.5712
# 2025-11-29 11:11:13,229 - supervised_finetuning - INFO - Epoch 1568 - supervised_accuracy/batch: 79.6875
# 2025-11-29 11:11:13,229 - supervised_finetuning - INFO - Epoch 1568 - learning_rate: 0.0001
# Classifier Epoch 99/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.8056, Acc=67.19%]2025-11-29 11:11:13,274 - supervised_finetuning - INFO - Epoch 1578 - supervised_loss/batch: 0.8056
# 2025-11-29 11:11:13,274 - supervised_finetuning - INFO - Epoch 1578 - supervised_accuracy/batch: 67.1875
# 2025-11-29 11:11:13,275 - supervised_finetuning - INFO - Epoch 1578 - learning_rate: 0.0001
# Classifier Epoch 99/100: 100% 16/16 [00:00<00:00, 226.79it/s, Loss=0.5536, Acc=78.18%]
# 2025-11-29 11:11:13,304 - supervised_finetuning - INFO - Epoch 99:
# 2025-11-29 11:11:13,304 - supervised_finetuning - INFO -   Train Loss: 0.6408, Train Acc: 73.40%
# 2025-11-29 11:11:13,305 - supervised_finetuning - INFO -   Train F1: 73.82%, Train Recall: 73.40%
# 2025-11-29 11:11:13,305 - supervised_finetuning - INFO -   Train Precision: 75.18%
# 2025-11-29 11:11:13,305 - supervised_finetuning - INFO - Epoch 98 - supervised_loss/epoch: 0.6408
# 2025-11-29 11:11:13,305 - supervised_finetuning - INFO - Epoch 98 - supervised_accuracy/epoch: 73.3990
# 2025-11-29 11:11:13,305 - supervised_finetuning - INFO - Epoch 98 - supervised_f1/epoch: 73.8169
# 2025-11-29 11:11:13,305 - supervised_finetuning - INFO - Epoch 98 - supervised_recall/epoch: 73.3990
# 2025-11-29 11:11:13,306 - supervised_finetuning - INFO - Epoch 98 - supervised_precision/epoch: 75.1786
# Classifier Epoch 100/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7457, Acc=64.06%]2025-11-29 11:11:13,310 - supervised_finetuning - INFO - Epoch 1584 - supervised_loss/batch: 0.7457
# 2025-11-29 11:11:13,310 - supervised_finetuning - INFO - Epoch 1584 - supervised_accuracy/batch: 64.0625
# 2025-11-29 11:11:13,310 - supervised_finetuning - INFO - Epoch 1584 - learning_rate: 0.0001
# Classifier Epoch 100/100:   0% 0/16 [00:00<?, ?it/s, Loss=0.7136, Acc=67.19%]2025-11-29 11:11:13,350 - supervised_finetuning - INFO - Epoch 1594 - supervised_loss/batch: 0.7136
# 2025-11-29 11:11:13,350 - supervised_finetuning - INFO - Epoch 1594 - supervised_accuracy/batch: 67.1875
# 2025-11-29 11:11:13,350 - supervised_finetuning - INFO - Epoch 1594 - learning_rate: 0.0001
# Classifier Epoch 100/100: 100% 16/16 [00:00<00:00, 255.67it/s, Loss=0.5903, Acc=74.55%]
# 2025-11-29 11:11:13,377 - supervised_finetuning - INFO - Epoch 100:
# 2025-11-29 11:11:13,377 - supervised_finetuning - INFO -   Train Loss: 0.6289, Train Acc: 73.89%
# 2025-11-29 11:11:13,377 - supervised_finetuning - INFO -   Train F1: 74.05%, Train Recall: 73.89%
# 2025-11-29 11:11:13,377 - supervised_finetuning - INFO -   Train Precision: 74.81%
# 2025-11-29 11:11:13,377 - supervised_finetuning - INFO - Epoch 99 - supervised_loss/epoch: 0.6289
# 2025-11-29 11:11:13,378 - supervised_finetuning - INFO - Epoch 99 - supervised_accuracy/epoch: 73.8916
# 2025-11-29 11:11:13,378 - supervised_finetuning - INFO - Epoch 99 - supervised_f1/epoch: 74.0471
# 2025-11-29 11:11:13,378 - supervised_finetuning - INFO - Epoch 99 - supervised_recall/epoch: 73.8916
# 2025-11-29 11:11:13,378 - supervised_finetuning - INFO - Epoch 99 - supervised_precision/epoch: 74.8079
# 2025-11-29 11:11:14,602 - supervised_finetuning - INFO - Supervised fine-tuning completed! Best Train Acc: 74.09%
# 2025-11-29 11:11:14,603 - supervised_finetuning - INFO - ✓ Encoder: FROZEN (contrastive features)
# 2025-11-29 11:11:14,603 - supervised_finetuning - INFO - ✓ Classifier: TRAINED (on label features)
# 2025-11-29 11:11:14,603 - supervised_finetuning - INFO - === TWO-STAGE Supervised Fine-tuning Finished ===

# %% [markdown]
# ## 4. Model Evaluation (4-class dataset)

# %%
# testing / model evaluation:
# !python "/content/SSCLNet-Implementation/eval.py"
# Out:
# 2025-11-29 11:11:28.730832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764414688.761053   67955 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764414688.770672   67955 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764414688.793655   67955 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764414688.793691   67955 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764414688.793698   67955 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764414688.793704   67955 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-29 11:11:28.801170: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✓ All directories created
# ✓ All directories created
# 2025-11-29 11:11:32,812 - model_evaluation - INFO - === Model Evaluation on Test Set ===
# ================================================================================
# MODEL SUMMARY
# ================================================================================
# Model: SSCLNet
# Total trainable parameters: 25,669,524
# Model size: 98.12 MB
#
# Layer breakdown:
#   encoder.conv1.weight: 3,136
#   encoder.bn1.weight: 64
#   encoder.bn1.bias: 64
#   encoder.layer1.0.conv1.weight: 4,096
#   encoder.layer1.0.bn1.weight: 64
#   encoder.layer1.0.bn1.bias: 64
#   encoder.layer1.0.conv2.weight: 36,864
#   encoder.layer1.0.bn2.weight: 64
#   encoder.layer1.0.bn2.bias: 64
#   encoder.layer1.0.conv3.weight: 16,384
#   encoder.layer1.0.bn3.weight: 256
#   encoder.layer1.0.bn3.bias: 256
#   encoder.layer1.0.downsample.0.weight: 16,384
#   encoder.layer1.0.downsample.1.weight: 256
#   encoder.layer1.0.downsample.1.bias: 256
#   encoder.layer1.1.conv1.weight: 16,384
#   encoder.layer1.1.bn1.weight: 64
#   encoder.layer1.1.bn1.bias: 64
#   encoder.layer1.1.conv2.weight: 36,864
#   encoder.layer1.1.bn2.weight: 64
#   encoder.layer1.1.bn2.bias: 64
#   encoder.layer1.1.conv3.weight: 16,384
#   encoder.layer1.1.bn3.weight: 256
#   encoder.layer1.1.bn3.bias: 256
#   encoder.layer1.2.conv1.weight: 16,384
#   encoder.layer1.2.bn1.weight: 64
#   encoder.layer1.2.bn1.bias: 64
#   encoder.layer1.2.conv2.weight: 36,864
#   encoder.layer1.2.bn2.weight: 64
#   encoder.layer1.2.bn2.bias: 64
#   encoder.layer1.2.conv3.weight: 16,384
#   encoder.layer1.2.bn3.weight: 256
#   encoder.layer1.2.bn3.bias: 256
#   encoder.layer2.0.conv1.weight: 32,768
#   encoder.layer2.0.bn1.weight: 128
#   encoder.layer2.0.bn1.bias: 128
#   encoder.layer2.0.conv2.weight: 147,456
#   encoder.layer2.0.bn2.weight: 128
#   encoder.layer2.0.bn2.bias: 128
#   encoder.layer2.0.conv3.weight: 65,536
#   encoder.layer2.0.bn3.weight: 512
#   encoder.layer2.0.bn3.bias: 512
#   encoder.layer2.0.downsample.0.weight: 131,072
#   encoder.layer2.0.downsample.1.weight: 512
#   encoder.layer2.0.downsample.1.bias: 512
#   encoder.layer2.1.conv1.weight: 65,536
#   encoder.layer2.1.bn1.weight: 128
#   encoder.layer2.1.bn1.bias: 128
#   encoder.layer2.1.conv2.weight: 147,456
#   encoder.layer2.1.bn2.weight: 128
#   encoder.layer2.1.bn2.bias: 128
#   encoder.layer2.1.conv3.weight: 65,536
#   encoder.layer2.1.bn3.weight: 512
#   encoder.layer2.1.bn3.bias: 512
#   encoder.layer2.2.conv1.weight: 65,536
#   encoder.layer2.2.bn1.weight: 128
#   encoder.layer2.2.bn1.bias: 128
#   encoder.layer2.2.conv2.weight: 147,456
#   encoder.layer2.2.bn2.weight: 128
#   encoder.layer2.2.bn2.bias: 128
#   encoder.layer2.2.conv3.weight: 65,536
#   encoder.layer2.2.bn3.weight: 512
#   encoder.layer2.2.bn3.bias: 512
#   encoder.layer2.3.conv1.weight: 65,536
#   encoder.layer2.3.bn1.weight: 128
#   encoder.layer2.3.bn1.bias: 128
#   encoder.layer2.3.conv2.weight: 147,456
#   encoder.layer2.3.bn2.weight: 128
#   encoder.layer2.3.bn2.bias: 128
#   encoder.layer2.3.conv3.weight: 65,536
#   encoder.layer2.3.bn3.weight: 512
#   encoder.layer2.3.bn3.bias: 512
#   encoder.layer3.0.conv1.weight: 131,072
#   encoder.layer3.0.bn1.weight: 256
#   encoder.layer3.0.bn1.bias: 256
#   encoder.layer3.0.conv2.weight: 589,824
#   encoder.layer3.0.bn2.weight: 256
#   encoder.layer3.0.bn2.bias: 256
#   encoder.layer3.0.conv3.weight: 262,144
#   encoder.layer3.0.bn3.weight: 1,024
#   encoder.layer3.0.bn3.bias: 1,024
#   encoder.layer3.0.downsample.0.weight: 524,288
#   encoder.layer3.0.downsample.1.weight: 1,024
#   encoder.layer3.0.downsample.1.bias: 1,024
#   encoder.layer3.1.conv1.weight: 262,144
#   encoder.layer3.1.bn1.weight: 256
#   encoder.layer3.1.bn1.bias: 256
#   encoder.layer3.1.conv2.weight: 589,824
#   encoder.layer3.1.bn2.weight: 256
#   encoder.layer3.1.bn2.bias: 256
#   encoder.layer3.1.conv3.weight: 262,144
#   encoder.layer3.1.bn3.weight: 1,024
#   encoder.layer3.1.bn3.bias: 1,024
#   encoder.layer3.2.conv1.weight: 262,144
#   encoder.layer3.2.bn1.weight: 256
#   encoder.layer3.2.bn1.bias: 256
#   encoder.layer3.2.conv2.weight: 589,824
#   encoder.layer3.2.bn2.weight: 256
#   encoder.layer3.2.bn2.bias: 256
#   encoder.layer3.2.conv3.weight: 262,144
#   encoder.layer3.2.bn3.weight: 1,024
#   encoder.layer3.2.bn3.bias: 1,024
#   encoder.layer3.3.conv1.weight: 262,144
#   encoder.layer3.3.bn1.weight: 256
#   encoder.layer3.3.bn1.bias: 256
#   encoder.layer3.3.conv2.weight: 589,824
#   encoder.layer3.3.bn2.weight: 256
#   encoder.layer3.3.bn2.bias: 256
#   encoder.layer3.3.conv3.weight: 262,144
#   encoder.layer3.3.bn3.weight: 1,024
#   encoder.layer3.3.bn3.bias: 1,024
#   encoder.layer3.4.conv1.weight: 262,144
#   encoder.layer3.4.bn1.weight: 256
#   encoder.layer3.4.bn1.bias: 256
#   encoder.layer3.4.conv2.weight: 589,824
#   encoder.layer3.4.bn2.weight: 256
#   encoder.layer3.4.bn2.bias: 256
#   encoder.layer3.4.conv3.weight: 262,144
#   encoder.layer3.4.bn3.weight: 1,024
#   encoder.layer3.4.bn3.bias: 1,024
#   encoder.layer3.5.conv1.weight: 262,144
#   encoder.layer3.5.bn1.weight: 256
#   encoder.layer3.5.bn1.bias: 256
#   encoder.layer3.5.conv2.weight: 589,824
#   encoder.layer3.5.bn2.weight: 256
#   encoder.layer3.5.bn2.bias: 256
#   encoder.layer3.5.conv3.weight: 262,144
#   encoder.layer3.5.bn3.weight: 1,024
#   encoder.layer3.5.bn3.bias: 1,024
#   encoder.layer4.0.conv1.weight: 524,288
#   encoder.layer4.0.bn1.weight: 512
#   encoder.layer4.0.bn1.bias: 512
#   encoder.layer4.0.conv2.weight: 2,359,296
#   encoder.layer4.0.bn2.weight: 512
#   encoder.layer4.0.bn2.bias: 512
#   encoder.layer4.0.conv3.weight: 1,048,576
#   encoder.layer4.0.bn3.weight: 2,048
#   encoder.layer4.0.bn3.bias: 2,048
#   encoder.layer4.0.downsample.0.weight: 2,097,152
#   encoder.layer4.0.downsample.1.weight: 2,048
#   encoder.layer4.0.downsample.1.bias: 2,048
#   encoder.layer4.1.conv1.weight: 1,048,576
#   encoder.layer4.1.bn1.weight: 512
#   encoder.layer4.1.bn1.bias: 512
#   encoder.layer4.1.conv2.weight: 2,359,296
#   encoder.layer4.1.bn2.weight: 512
#   encoder.layer4.1.bn2.bias: 512
#   encoder.layer4.1.conv3.weight: 1,048,576
#   encoder.layer4.1.bn3.weight: 2,048
#   encoder.layer4.1.bn3.bias: 2,048
#   encoder.layer4.2.conv1.weight: 1,048,576
#   encoder.layer4.2.bn1.weight: 512
#   encoder.layer4.2.bn1.bias: 512
#   encoder.layer4.2.conv2.weight: 2,359,296
#   encoder.layer4.2.bn2.weight: 512
#   encoder.layer4.2.bn2.bias: 512
#   encoder.layer4.2.conv3.weight: 1,048,576
#   encoder.layer4.2.bn3.weight: 2,048
#   encoder.layer4.2.bn3.bias: 2,048
#   projection_head.mlp.0.weight: 1,048,576
#   projection_head.mlp.0.bias: 512
#   projection_head.mlp.2.weight: 262,144
#   projection_head.mlp.2.bias: 512
#   projection_head.mlp.4.weight: 131,072
#   projection_head.mlp.4.bias: 256
#   projection_head.mlp.6.weight: 65,536
#   projection_head.mlp.6.bias: 256
#   projection_head.mlp.9.weight: 8,192
#   projection_head.mlp.9.bias: 32
#   classifier.classifier.0.weight: 524,288
#   classifier.classifier.0.bias: 256
#   classifier.classifier.2.weight: 65,536
#   classifier.classifier.2.bias: 256
#   classifier.classifier.4.weight: 32,768
#   classifier.classifier.4.bias: 128
#   classifier.classifier.6.weight: 16,384
#   classifier.classifier.6.bias: 128
#   classifier.classifier.8.weight: 8,192
#   classifier.classifier.8.bias: 64
#   classifier.classifier.10.weight: 2,048
#   classifier.classifier.10.bias: 32
#   classifier.classifier.12.weight: 512
#   classifier.classifier.12.bias: 16
#   classifier.classifier.14.weight: 64
#   classifier.classifier.14.bias: 4
# ================================================================================
# Created test DataLoader:
#   - Batch size: 64
#   - Shuffle: False
#   - Workers: 2
#   - Classes: ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
#   - Number of samples: 492
# ==================================================
# DATASET ANALYSIS
# ==================================================
# Total samples: 492
# Class distribution:
#   glioma_tumor: 226 (45.9%)
#   meningioma_tumor: 109 (22.2%)
#   no_tumor: 67 (13.6%)
#   pituitary_tumor: 90 (18.3%)
# 2025-11-29 11:11:34,497 - model_evaluation - INFO - Evaluating on 492 test samples
# 2025-11-29 11:11:34,498 - model_evaluation - INFO - Running evaluation on test set...
# 2025-11-29 11:11:36,415 - model_evaluation - INFO -
# ==================================================
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - FINAL TEST RESULTS
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - Test Loss: 0.6711
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - Test Accuracy: 73.37%
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - Test Precision: 75.90%
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - Test Recall: 73.37%
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - Test F1-Score: 73.94%
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:11:36,415 - model_evaluation - INFO -
# DETAILED CLASSIFICATION REPORT:
# 2025-11-29 11:11:36,415 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:11:36,422 - model_evaluation - INFO -
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.87      0.77      0.82       226
# meningioma_tumor       0.56      0.58      0.57       109
#         no_tumor       0.56      0.87      0.68        67
#  pituitary_tumor       0.86      0.73      0.79        90
#
#         accuracy                           0.73       492
#        macro avg       0.71      0.74      0.71       492
#     weighted avg       0.76      0.73      0.74       492
#
# 2025-11-29 11:11:36,423 - model_evaluation - INFO -
# CONFUSION MATRIX:
# 2025-11-29 11:11:36,423 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:11:36,429 - model_evaluation - INFO -
# [[174  40   9   3]
#  [ 20  63  20   6]
#  [  3   4  58   2]
#  [  2   5  17  66]]
# 2025-11-29 11:11:37,136 - model_evaluation - INFO - Confusion matrix saved as 'plots/confusion_matrix.png'
# 2025-11-29 11:11:37,136 - model_evaluation - INFO -
# ==================================================
# 2025-11-29 11:11:37,136 - model_evaluation - INFO - ROC CURVE ANALYSIS
# 2025-11-29 11:11:37,136 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:11:38,080 - model_evaluation - INFO - ROC curve saved as 'plots/roc_curve.png'
# 2025-11-29 11:11:38,081 - model_evaluation - INFO -
# AUC Scores:
# 2025-11-29 11:11:38,081 - model_evaluation - INFO -   glioma_tumor: 0.9266
# 2025-11-29 11:11:38,081 - model_evaluation - INFO -   meningioma_tumor: 0.8166
# 2025-11-29 11:11:38,081 - model_evaluation - INFO -   no_tumor: 0.9318
# 2025-11-29 11:11:38,081 - model_evaluation - INFO -   pituitary_tumor: 0.9648
# 2025-11-29 11:11:38,081 - model_evaluation - INFO -   Micro-average: 0.9236
# 2025-11-29 11:11:38,081 - model_evaluation - INFO -
# PER-CLASS ACCURACY:
# 2025-11-29 11:11:38,081 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:11:38,081 - model_evaluation - INFO - glioma_tumor: 76.99%
# 2025-11-29 11:11:38,081 - model_evaluation - INFO - meningioma_tumor: 57.80%
# 2025-11-29 11:11:38,081 - model_evaluation - INFO - no_tumor: 86.57%
# 2025-11-29 11:11:38,081 - model_evaluation - INFO - pituitary_tumor: 73.33%
# 2025-11-29 11:11:38,082 - model_evaluation - INFO - === Model Evaluation Completed ===
# fatal: not a git repository (or any of the parent directories): .git
# ✓ Results saved to: results/final_evaluation_results.json
#
# ✓ Evaluation completed! Check:
#   - logs/model_evaluation.log for detailed logs
#   - results/final_evaluation_results.json for comprehensive results
#   - plots/ for confusion matrix and ROC curves

# %%
# !zip -r /content/plots_4Class.zip /content/plots
# Out:
#   adding: content/plots/ (stored 0%)
#   adding: content/plots/contrastive_loss.png (deflated 24%)
#   adding: content/plots/roc_curve.png (deflated 20%)
#   adding: content/plots/class_distribution.png (deflated 28%)
#   adding: content/plots/confusion_matrix.png (deflated 26%)
#   adding: content/plots/supervised_training_history.png (deflated 28%)

# %%
# !zip -r /content/logs_4Class.zip /content/logs
# Out:
#   adding: content/logs/ (stored 0%)
#   adding: content/logs/supervised_finetuning.log (deflated 91%)
#   adding: content/logs/contrastive_pretraining.log (deflated 89%)
#   adding: content/logs/model_evaluation.log (deflated 79%)

# %% [markdown]
# ## 5. Training Phase 2 - Supervised Learning (2-class dataset)
#
# **Note:** Update the path to `TRAIN_DATA_PATH`, `TEST_DATA_PATH` and `NUM_CLASSES` in `config.py` to the 2-class dataset.

# %%
# !python "/content/SSCLNet-Implementation/train_supervised.py"
# Out:
# 2025-11-29 11:30:19.337051: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764415819.356851   72774 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764415819.362907   72774 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764415819.377926   72774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764415819.377952   72774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764415819.377956   72774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764415819.377960   72774 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-29 11:30:19.382477: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✓ All directories created
# ✓ All directories created
# ✓ Random seed set to: 42
# 2025-11-29 11:30:23,581 - supervised_finetuning - INFO - === Starting TWO-STAGE Supervised Fine-tuning ===
# Skipping classifier layer: classifier.classifier.0.weight
# Skipping classifier layer: classifier.classifier.0.bias
# Skipping classifier layer: classifier.classifier.2.weight
# Skipping classifier layer: classifier.classifier.2.bias
# Skipping classifier layer: classifier.classifier.4.weight
# Skipping classifier layer: classifier.classifier.4.bias
# Skipping classifier layer: classifier.classifier.6.weight
# Skipping classifier layer: classifier.classifier.6.bias
# Skipping classifier layer: classifier.classifier.8.weight
# Skipping classifier layer: classifier.classifier.8.bias
# Skipping classifier layer: classifier.classifier.10.weight
# Skipping classifier layer: classifier.classifier.10.bias
# Skipping classifier layer: classifier.classifier.12.weight
# Skipping classifier layer: classifier.classifier.12.bias
# Skipping classifier layer: classifier.classifier.14.weight
# Skipping classifier layer: classifier.classifier.14.bias
# ✓ Loaded pre-trained encoder & projection head weights
# 2025-11-29 11:30:24,144 - supervised_finetuning - INFO - ✓ Loaded pre-trained weights from contrastive training!
# ================================================================================
# MODEL SUMMARY
# ================================================================================
# Model: SSCLNet
# Total trainable parameters: 25,669,490
# Model size: 98.12 MB
#
# Layer breakdown:
#   encoder.conv1.weight: 3,136
#   encoder.bn1.weight: 64
#   encoder.bn1.bias: 64
#   encoder.layer1.0.conv1.weight: 4,096
#   encoder.layer1.0.bn1.weight: 64
#   encoder.layer1.0.bn1.bias: 64
#   encoder.layer1.0.conv2.weight: 36,864
#   encoder.layer1.0.bn2.weight: 64
#   encoder.layer1.0.bn2.bias: 64
#   encoder.layer1.0.conv3.weight: 16,384
#   encoder.layer1.0.bn3.weight: 256
#   encoder.layer1.0.bn3.bias: 256
#   encoder.layer1.0.downsample.0.weight: 16,384
#   encoder.layer1.0.downsample.1.weight: 256
#   encoder.layer1.0.downsample.1.bias: 256
#   encoder.layer1.1.conv1.weight: 16,384
#   encoder.layer1.1.bn1.weight: 64
#   encoder.layer1.1.bn1.bias: 64
#   encoder.layer1.1.conv2.weight: 36,864
#   encoder.layer1.1.bn2.weight: 64
#   encoder.layer1.1.bn2.bias: 64
#   encoder.layer1.1.conv3.weight: 16,384
#   encoder.layer1.1.bn3.weight: 256
#   encoder.layer1.1.bn3.bias: 256
#   encoder.layer1.2.conv1.weight: 16,384
#   encoder.layer1.2.bn1.weight: 64
#   encoder.layer1.2.bn1.bias: 64
#   encoder.layer1.2.conv2.weight: 36,864
#   encoder.layer1.2.bn2.weight: 64
#   encoder.layer1.2.bn2.bias: 64
#   encoder.layer1.2.conv3.weight: 16,384
#   encoder.layer1.2.bn3.weight: 256
#   encoder.layer1.2.bn3.bias: 256
#   encoder.layer2.0.conv1.weight: 32,768
#   encoder.layer2.0.bn1.weight: 128
#   encoder.layer2.0.bn1.bias: 128
#   encoder.layer2.0.conv2.weight: 147,456
#   encoder.layer2.0.bn2.weight: 128
#   encoder.layer2.0.bn2.bias: 128
#   encoder.layer2.0.conv3.weight: 65,536
#   encoder.layer2.0.bn3.weight: 512
#   encoder.layer2.0.bn3.bias: 512
#   encoder.layer2.0.downsample.0.weight: 131,072
#   encoder.layer2.0.downsample.1.weight: 512
#   encoder.layer2.0.downsample.1.bias: 512
#   encoder.layer2.1.conv1.weight: 65,536
#   encoder.layer2.1.bn1.weight: 128
#   encoder.layer2.1.bn1.bias: 128
#   encoder.layer2.1.conv2.weight: 147,456
#   encoder.layer2.1.bn2.weight: 128
#   encoder.layer2.1.bn2.bias: 128
#   encoder.layer2.1.conv3.weight: 65,536
#   encoder.layer2.1.bn3.weight: 512
#   encoder.layer2.1.bn3.bias: 512
#   encoder.layer2.2.conv1.weight: 65,536
#   encoder.layer2.2.bn1.weight: 128
#   encoder.layer2.2.bn1.bias: 128
#   encoder.layer2.2.conv2.weight: 147,456
#   encoder.layer2.2.bn2.weight: 128
#   encoder.layer2.2.bn2.bias: 128
#   encoder.layer2.2.conv3.weight: 65,536
#   encoder.layer2.2.bn3.weight: 512
#   encoder.layer2.2.bn3.bias: 512
#   encoder.layer2.3.conv1.weight: 65,536
#   encoder.layer2.3.bn1.weight: 128
#   encoder.layer2.3.bn1.bias: 128
#   encoder.layer2.3.conv2.weight: 147,456
#   encoder.layer2.3.bn2.weight: 128
#   encoder.layer2.3.bn2.bias: 128
#   encoder.layer2.3.conv3.weight: 65,536
#   encoder.layer2.3.bn3.weight: 512
#   encoder.layer2.3.bn3.bias: 512
#   encoder.layer3.0.conv1.weight: 131,072
#   encoder.layer3.0.bn1.weight: 256
#   encoder.layer3.0.bn1.bias: 256
#   encoder.layer3.0.conv2.weight: 589,824
#   encoder.layer3.0.bn2.weight: 256
#   encoder.layer3.0.bn2.bias: 256
#   encoder.layer3.0.conv3.weight: 262,144
#   encoder.layer3.0.bn3.weight: 1,024
#   encoder.layer3.0.bn3.bias: 1,024
#   encoder.layer3.0.downsample.0.weight: 524,288
#   encoder.layer3.0.downsample.1.weight: 1,024
#   encoder.layer3.0.downsample.1.bias: 1,024
#   encoder.layer3.1.conv1.weight: 262,144
#   encoder.layer3.1.bn1.weight: 256
#   encoder.layer3.1.bn1.bias: 256
#   encoder.layer3.1.conv2.weight: 589,824
#   encoder.layer3.1.bn2.weight: 256
#   encoder.layer3.1.bn2.bias: 256
#   encoder.layer3.1.conv3.weight: 262,144
#   encoder.layer3.1.bn3.weight: 1,024
#   encoder.layer3.1.bn3.bias: 1,024
#   encoder.layer3.2.conv1.weight: 262,144
#   encoder.layer3.2.bn1.weight: 256
#   encoder.layer3.2.bn1.bias: 256
#   encoder.layer3.2.conv2.weight: 589,824
#   encoder.layer3.2.bn2.weight: 256
#   encoder.layer3.2.bn2.bias: 256
#   encoder.layer3.2.conv3.weight: 262,144
#   encoder.layer3.2.bn3.weight: 1,024
#   encoder.layer3.2.bn3.bias: 1,024
#   encoder.layer3.3.conv1.weight: 262,144
#   encoder.layer3.3.bn1.weight: 256
#   encoder.layer3.3.bn1.bias: 256
#   encoder.layer3.3.conv2.weight: 589,824
#   encoder.layer3.3.bn2.weight: 256
#   encoder.layer3.3.bn2.bias: 256
#   encoder.layer3.3.conv3.weight: 262,144
#   encoder.layer3.3.bn3.weight: 1,024
#   encoder.layer3.3.bn3.bias: 1,024
#   encoder.layer3.4.conv1.weight: 262,144
#   encoder.layer3.4.bn1.weight: 256
#   encoder.layer3.4.bn1.bias: 256
#   encoder.layer3.4.conv2.weight: 589,824
#   encoder.layer3.4.bn2.weight: 256
#   encoder.layer3.4.bn2.bias: 256
#   encoder.layer3.4.conv3.weight: 262,144
#   encoder.layer3.4.bn3.weight: 1,024
#   encoder.layer3.4.bn3.bias: 1,024
#   encoder.layer3.5.conv1.weight: 262,144
#   encoder.layer3.5.bn1.weight: 256
#   encoder.layer3.5.bn1.bias: 256
#   encoder.layer3.5.conv2.weight: 589,824
#   encoder.layer3.5.bn2.weight: 256
#   encoder.layer3.5.bn2.bias: 256
#   encoder.layer3.5.conv3.weight: 262,144
#   encoder.layer3.5.bn3.weight: 1,024
#   encoder.layer3.5.bn3.bias: 1,024
#   encoder.layer4.0.conv1.weight: 524,288
#   encoder.layer4.0.bn1.weight: 512
#   encoder.layer4.0.bn1.bias: 512
#   encoder.layer4.0.conv2.weight: 2,359,296
#   encoder.layer4.0.bn2.weight: 512
#   encoder.layer4.0.bn2.bias: 512
#   encoder.layer4.0.conv3.weight: 1,048,576
#   encoder.layer4.0.bn3.weight: 2,048
#   encoder.layer4.0.bn3.bias: 2,048
#   encoder.layer4.0.downsample.0.weight: 2,097,152
#   encoder.layer4.0.downsample.1.weight: 2,048
#   encoder.layer4.0.downsample.1.bias: 2,048
#   encoder.layer4.1.conv1.weight: 1,048,576
#   encoder.layer4.1.bn1.weight: 512
#   encoder.layer4.1.bn1.bias: 512
#   encoder.layer4.1.conv2.weight: 2,359,296
#   encoder.layer4.1.bn2.weight: 512
#   encoder.layer4.1.bn2.bias: 512
#   encoder.layer4.1.conv3.weight: 1,048,576
#   encoder.layer4.1.bn3.weight: 2,048
#   encoder.layer4.1.bn3.bias: 2,048
#   encoder.layer4.2.conv1.weight: 1,048,576
#   encoder.layer4.2.bn1.weight: 512
#   encoder.layer4.2.bn1.bias: 512
#   encoder.layer4.2.conv2.weight: 2,359,296
#   encoder.layer4.2.bn2.weight: 512
#   encoder.layer4.2.bn2.bias: 512
#   encoder.layer4.2.conv3.weight: 1,048,576
#   encoder.layer4.2.bn3.weight: 2,048
#   encoder.layer4.2.bn3.bias: 2,048
#   projection_head.mlp.0.weight: 1,048,576
#   projection_head.mlp.0.bias: 512
#   projection_head.mlp.2.weight: 262,144
#   projection_head.mlp.2.bias: 512
#   projection_head.mlp.4.weight: 131,072
#   projection_head.mlp.4.bias: 256
#   projection_head.mlp.6.weight: 65,536
#   projection_head.mlp.6.bias: 256
#   projection_head.mlp.9.weight: 8,192
#   projection_head.mlp.9.bias: 32
#   classifier.classifier.0.weight: 524,288
#   classifier.classifier.0.bias: 256
#   classifier.classifier.2.weight: 65,536
#   classifier.classifier.2.bias: 256
#   classifier.classifier.4.weight: 32,768
#   classifier.classifier.4.bias: 128
#   classifier.classifier.6.weight: 16,384
#   classifier.classifier.6.bias: 128
#   classifier.classifier.8.weight: 8,192
#   classifier.classifier.8.bias: 64
#   classifier.classifier.10.weight: 2,048
#   classifier.classifier.10.bias: 32
#   classifier.classifier.12.weight: 512
#   classifier.classifier.12.bias: 16
#   classifier.classifier.14.weight: 32
#   classifier.classifier.14.bias: 2
# ================================================================================
# 2025-11-29 11:30:24,352 - supervised_finetuning - INFO - ✓ Encoder frozen - only classifier will be trained
# Created train DataLoader:
#   - Batch size: 64
#   - Shuffle: True
#   - Workers: 2
#   - Classes: ['no', 'yes']
#   - Number of samples: 1199
# ==================================================
# DATASET ANALYSIS
# ==================================================
# Total samples: 1199
# Class distribution:
#   yes: 617 (51.5%)
#   no: 582 (48.5%)
# 2025-11-29 11:30:26,614 - supervised_finetuning - INFO - Training with 1199 labeled images
# 2025-11-29 11:30:26,614 - supervised_finetuning - INFO - === STAGE 1: Extracting Label Features ===
# Extracting features: 100% 19/19 [00:03<00:00,  5.22it/s]
# 2025-11-29 11:30:30,267 - supervised_finetuning - INFO - ✓ Extracted 1199 label features with shape torch.Size([1199, 2048])
# 2025-11-29 11:30:30,268 - supervised_finetuning - INFO - ✓ Created feature dataset for classifier training
# 2025-11-29 11:30:30,268 - supervised_finetuning - INFO - === STAGE 2: Training Classifier on Label Features ===
# Classifier Epoch 1/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6882, Acc=57.81%]2025-11-29 11:30:30,400 - supervised_finetuning - INFO - Epoch 0 - supervised_loss/batch: 0.6882
# 2025-11-29 11:30:30,401 - supervised_finetuning - INFO - Epoch 0 - supervised_accuracy/batch: 57.8125
# 2025-11-29 11:30:30,401 - supervised_finetuning - INFO - Epoch 0 - learning_rate: 0.0001
# Classifier Epoch 1/100:   5% 1/19 [00:00<00:02,  7.51it/s, Loss=0.6903, Acc=53.12%]2025-11-29 11:30:30,437 - supervised_finetuning - INFO - Epoch 10 - supervised_loss/batch: 0.6903
# 2025-11-29 11:30:30,437 - supervised_finetuning - INFO - Epoch 10 - supervised_accuracy/batch: 53.1250
# 2025-11-29 11:30:30,438 - supervised_finetuning - INFO - Epoch 10 - learning_rate: 0.0001
# Classifier Epoch 1/100: 100% 19/19 [00:00<00:00, 96.39it/s, Loss=0.6978, Acc=42.55%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2025-11-29 11:30:30,477 - supervised_finetuning - INFO - Epoch 1:
# 2025-11-29 11:30:30,477 - supervised_finetuning - INFO -   Train Loss: 0.6939, Train Acc: 48.54%
# 2025-11-29 11:30:30,477 - supervised_finetuning - INFO -   Train F1: 31.72%, Train Recall: 48.54%
# 2025-11-29 11:30:30,478 - supervised_finetuning - INFO -   Train Precision: 23.56%
# 2025-11-29 11:30:30,478 - supervised_finetuning - INFO - Epoch 0 - supervised_loss/epoch: 0.6939
# 2025-11-29 11:30:30,478 - supervised_finetuning - INFO - Epoch 0 - supervised_accuracy/epoch: 48.5405
# 2025-11-29 11:30:30,478 - supervised_finetuning - INFO - Epoch 0 - supervised_f1/epoch: 31.7244
# 2025-11-29 11:30:30,478 - supervised_finetuning - INFO - Epoch 0 - supervised_recall/epoch: 48.5405
# 2025-11-29 11:30:30,479 - supervised_finetuning - INFO - Epoch 0 - supervised_precision/epoch: 23.5618
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:30,878 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 48.54%
# Classifier Epoch 2/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6892, Acc=53.12%]2025-11-29 11:30:30,884 - supervised_finetuning - INFO - Epoch 19 - supervised_loss/batch: 0.6892
# 2025-11-29 11:30:30,885 - supervised_finetuning - INFO - Epoch 19 - supervised_accuracy/batch: 53.1250
# 2025-11-29 11:30:30,885 - supervised_finetuning - INFO - Epoch 19 - learning_rate: 0.0001
# Classifier Epoch 2/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6875, Acc=59.38%]2025-11-29 11:30:30,920 - supervised_finetuning - INFO - Epoch 29 - supervised_loss/batch: 0.6875
# 2025-11-29 11:30:30,920 - supervised_finetuning - INFO - Epoch 29 - supervised_accuracy/batch: 59.3750
# 2025-11-29 11:30:30,920 - supervised_finetuning - INFO - Epoch 29 - learning_rate: 0.0001
# Classifier Epoch 2/100: 100% 19/19 [00:00<00:00, 278.20it/s, Loss=0.6848, Acc=59.57%]
# 2025-11-29 11:30:30,958 - supervised_finetuning - INFO - Epoch 2:
# 2025-11-29 11:30:30,958 - supervised_finetuning - INFO -   Train Loss: 0.6887, Train Acc: 55.63%
# 2025-11-29 11:30:30,958 - supervised_finetuning - INFO -   Train F1: 49.94%, Train Recall: 55.63%
# 2025-11-29 11:30:30,958 - supervised_finetuning - INFO -   Train Precision: 62.54%
# 2025-11-29 11:30:30,958 - supervised_finetuning - INFO - Epoch 1 - supervised_loss/epoch: 0.6887
# 2025-11-29 11:30:30,958 - supervised_finetuning - INFO - Epoch 1 - supervised_accuracy/epoch: 55.6297
# 2025-11-29 11:30:30,958 - supervised_finetuning - INFO - Epoch 1 - supervised_f1/epoch: 49.9402
# 2025-11-29 11:30:30,959 - supervised_finetuning - INFO - Epoch 1 - supervised_recall/epoch: 55.6297
# 2025-11-29 11:30:30,959 - supervised_finetuning - INFO - Epoch 1 - supervised_precision/epoch: 62.5380
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:31,567 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 55.63%
# Classifier Epoch 3/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6782, Acc=62.50%]2025-11-29 11:30:31,573 - supervised_finetuning - INFO - Epoch 38 - supervised_loss/batch: 0.6782
# 2025-11-29 11:30:31,573 - supervised_finetuning - INFO - Epoch 38 - supervised_accuracy/batch: 62.5000
# 2025-11-29 11:30:31,573 - supervised_finetuning - INFO - Epoch 38 - learning_rate: 0.0001
# Classifier Epoch 3/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6812, Acc=56.25%]2025-11-29 11:30:31,623 - supervised_finetuning - INFO - Epoch 48 - supervised_loss/batch: 0.6812
# 2025-11-29 11:30:31,623 - supervised_finetuning - INFO - Epoch 48 - supervised_accuracy/batch: 56.2500
# 2025-11-29 11:30:31,623 - supervised_finetuning - INFO - Epoch 48 - learning_rate: 0.0001
# Classifier Epoch 3/100: 100% 19/19 [00:00<00:00, 227.85it/s, Loss=0.6556, Acc=63.83%]
# 2025-11-29 11:30:31,662 - supervised_finetuning - INFO - Epoch 3:
# 2025-11-29 11:30:31,662 - supervised_finetuning - INFO -   Train Loss: 0.6759, Train Acc: 63.47%
# 2025-11-29 11:30:31,662 - supervised_finetuning - INFO -   Train F1: 63.13%, Train Recall: 63.47%
# 2025-11-29 11:30:31,662 - supervised_finetuning - INFO -   Train Precision: 63.66%
# 2025-11-29 11:30:31,662 - supervised_finetuning - INFO - Epoch 2 - supervised_loss/epoch: 0.6759
# 2025-11-29 11:30:31,663 - supervised_finetuning - INFO - Epoch 2 - supervised_accuracy/epoch: 63.4696
# 2025-11-29 11:30:31,663 - supervised_finetuning - INFO - Epoch 2 - supervised_f1/epoch: 63.1342
# 2025-11-29 11:30:31,663 - supervised_finetuning - INFO - Epoch 2 - supervised_recall/epoch: 63.4696
# 2025-11-29 11:30:31,663 - supervised_finetuning - INFO - Epoch 2 - supervised_precision/epoch: 63.6623
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:32,399 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 63.47%
# Classifier Epoch 4/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6653, Acc=62.50%]2025-11-29 11:30:32,404 - supervised_finetuning - INFO - Epoch 57 - supervised_loss/batch: 0.6653
# 2025-11-29 11:30:32,404 - supervised_finetuning - INFO - Epoch 57 - supervised_accuracy/batch: 62.5000
# 2025-11-29 11:30:32,404 - supervised_finetuning - INFO - Epoch 57 - learning_rate: 0.0001
# Classifier Epoch 4/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6763, Acc=59.38%]2025-11-29 11:30:32,442 - supervised_finetuning - INFO - Epoch 67 - supervised_loss/batch: 0.6763
# 2025-11-29 11:30:32,442 - supervised_finetuning - INFO - Epoch 67 - supervised_accuracy/batch: 59.3750
# 2025-11-29 11:30:32,443 - supervised_finetuning - INFO - Epoch 67 - learning_rate: 0.0001
# Classifier Epoch 4/100: 100% 19/19 [00:00<00:00, 254.65it/s, Loss=0.6434, Acc=65.96%]
# 2025-11-29 11:30:32,483 - supervised_finetuning - INFO - Epoch 4:
# 2025-11-29 11:30:32,484 - supervised_finetuning - INFO -   Train Loss: 0.6612, Train Acc: 62.64%
# 2025-11-29 11:30:32,484 - supervised_finetuning - INFO -   Train F1: 62.08%, Train Recall: 62.64%
# 2025-11-29 11:30:32,484 - supervised_finetuning - INFO -   Train Precision: 63.00%
# 2025-11-29 11:30:32,484 - supervised_finetuning - INFO - Epoch 3 - supervised_loss/epoch: 0.6612
# 2025-11-29 11:30:32,484 - supervised_finetuning - INFO - Epoch 3 - supervised_accuracy/epoch: 62.6355
# 2025-11-29 11:30:32,484 - supervised_finetuning - INFO - Epoch 3 - supervised_f1/epoch: 62.0830
# 2025-11-29 11:30:32,485 - supervised_finetuning - INFO - Epoch 3 - supervised_recall/epoch: 62.6355
# 2025-11-29 11:30:32,485 - supervised_finetuning - INFO - Epoch 3 - supervised_precision/epoch: 63.0001
# Classifier Epoch 5/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6631, Acc=64.06%]2025-11-29 11:30:32,489 - supervised_finetuning - INFO - Epoch 76 - supervised_loss/batch: 0.6631
# 2025-11-29 11:30:32,489 - supervised_finetuning - INFO - Epoch 76 - supervised_accuracy/batch: 64.0625
# 2025-11-29 11:30:32,490 - supervised_finetuning - INFO - Epoch 76 - learning_rate: 0.0001
# Classifier Epoch 5/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6297, Acc=70.31%]2025-11-29 11:30:32,525 - supervised_finetuning - INFO - Epoch 86 - supervised_loss/batch: 0.6297
# 2025-11-29 11:30:32,525 - supervised_finetuning - INFO - Epoch 86 - supervised_accuracy/batch: 70.3125
# 2025-11-29 11:30:32,525 - supervised_finetuning - INFO - Epoch 86 - learning_rate: 0.0001
# Classifier Epoch 5/100: 100% 19/19 [00:00<00:00, 278.24it/s, Loss=0.6523, Acc=61.70%]
# 2025-11-29 11:30:32,565 - supervised_finetuning - INFO - Epoch 5:
# 2025-11-29 11:30:32,565 - supervised_finetuning - INFO -   Train Loss: 0.6468, Train Acc: 66.31%
# 2025-11-29 11:30:32,565 - supervised_finetuning - INFO -   Train F1: 65.79%, Train Recall: 66.31%
# 2025-11-29 11:30:32,565 - supervised_finetuning - INFO -   Train Precision: 66.89%
# 2025-11-29 11:30:32,565 - supervised_finetuning - INFO - Epoch 4 - supervised_loss/epoch: 0.6468
# 2025-11-29 11:30:32,566 - supervised_finetuning - INFO - Epoch 4 - supervised_accuracy/epoch: 66.3053
# 2025-11-29 11:30:32,566 - supervised_finetuning - INFO - Epoch 4 - supervised_f1/epoch: 65.7928
# 2025-11-29 11:30:32,566 - supervised_finetuning - INFO - Epoch 4 - supervised_recall/epoch: 66.3053
# 2025-11-29 11:30:32,566 - supervised_finetuning - INFO - Epoch 4 - supervised_precision/epoch: 66.8943
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:33,242 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 66.31%
# Classifier Epoch 6/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6310, Acc=64.06%]2025-11-29 11:30:33,248 - supervised_finetuning - INFO - Epoch 95 - supervised_loss/batch: 0.6310
# 2025-11-29 11:30:33,248 - supervised_finetuning - INFO - Epoch 95 - supervised_accuracy/batch: 64.0625
# 2025-11-29 11:30:33,248 - supervised_finetuning - INFO - Epoch 95 - learning_rate: 0.0001
# Classifier Epoch 6/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.7062, Acc=67.19%]2025-11-29 11:30:33,286 - supervised_finetuning - INFO - Epoch 105 - supervised_loss/batch: 0.7062
# 2025-11-29 11:30:33,286 - supervised_finetuning - INFO - Epoch 105 - supervised_accuracy/batch: 67.1875
# 2025-11-29 11:30:33,286 - supervised_finetuning - INFO - Epoch 105 - learning_rate: 0.0001
# Classifier Epoch 6/100: 100% 19/19 [00:00<00:00, 241.36it/s, Loss=0.6744, Acc=55.32%]
# 2025-11-29 11:30:33,338 - supervised_finetuning - INFO - Epoch 6:
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO -   Train Loss: 0.6436, Train Acc: 66.31%
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO -   Train F1: 66.29%, Train Recall: 66.31%
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO -   Train Precision: 66.29%
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO - Epoch 5 - supervised_loss/epoch: 0.6436
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO - Epoch 5 - supervised_accuracy/epoch: 66.3053
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO - Epoch 5 - supervised_f1/epoch: 66.2947
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO - Epoch 5 - supervised_recall/epoch: 66.3053
# 2025-11-29 11:30:33,339 - supervised_finetuning - INFO - Epoch 5 - supervised_precision/epoch: 66.2934
# Classifier Epoch 7/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6267, Acc=65.62%]2025-11-29 11:30:33,344 - supervised_finetuning - INFO - Epoch 114 - supervised_loss/batch: 0.6267
# 2025-11-29 11:30:33,344 - supervised_finetuning - INFO - Epoch 114 - supervised_accuracy/batch: 65.6250
# 2025-11-29 11:30:33,344 - supervised_finetuning - INFO - Epoch 114 - learning_rate: 0.0001
# Classifier Epoch 7/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6267, Acc=64.06%]2025-11-29 11:30:33,383 - supervised_finetuning - INFO - Epoch 124 - supervised_loss/batch: 0.6267
# 2025-11-29 11:30:33,383 - supervised_finetuning - INFO - Epoch 124 - supervised_accuracy/batch: 64.0625
# 2025-11-29 11:30:33,383 - supervised_finetuning - INFO - Epoch 124 - learning_rate: 0.0001
# Classifier Epoch 7/100: 100% 19/19 [00:00<00:00, 256.23it/s, Loss=0.7040, Acc=48.94%]
# 2025-11-29 11:30:33,425 - supervised_finetuning - INFO - Epoch 7:
# 2025-11-29 11:30:33,425 - supervised_finetuning - INFO -   Train Loss: 0.6344, Train Acc: 66.06%
# 2025-11-29 11:30:33,425 - supervised_finetuning - INFO -   Train F1: 66.02%, Train Recall: 66.06%
# 2025-11-29 11:30:33,425 - supervised_finetuning - INFO -   Train Precision: 66.04%
# 2025-11-29 11:30:33,425 - supervised_finetuning - INFO - Epoch 6 - supervised_loss/epoch: 0.6344
# 2025-11-29 11:30:33,426 - supervised_finetuning - INFO - Epoch 6 - supervised_accuracy/epoch: 66.0550
# 2025-11-29 11:30:33,426 - supervised_finetuning - INFO - Epoch 6 - supervised_f1/epoch: 66.0235
# 2025-11-29 11:30:33,426 - supervised_finetuning - INFO - Epoch 6 - supervised_recall/epoch: 66.0550
# 2025-11-29 11:30:33,427 - supervised_finetuning - INFO - Epoch 6 - supervised_precision/epoch: 66.0406
# Classifier Epoch 8/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6022, Acc=70.31%]2025-11-29 11:30:33,431 - supervised_finetuning - INFO - Epoch 133 - supervised_loss/batch: 0.6022
# 2025-11-29 11:30:33,431 - supervised_finetuning - INFO - Epoch 133 - supervised_accuracy/batch: 70.3125
# 2025-11-29 11:30:33,432 - supervised_finetuning - INFO - Epoch 133 - learning_rate: 0.0001
# Classifier Epoch 8/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5827, Acc=76.56%]2025-11-29 11:30:33,470 - supervised_finetuning - INFO - Epoch 143 - supervised_loss/batch: 0.5827
# 2025-11-29 11:30:33,470 - supervised_finetuning - INFO - Epoch 143 - supervised_accuracy/batch: 76.5625
# 2025-11-29 11:30:33,471 - supervised_finetuning - INFO - Epoch 143 - learning_rate: 0.0001
# Classifier Epoch 8/100: 100% 19/19 [00:00<00:00, 258.90it/s, Loss=0.6380, Acc=68.09%]
# 2025-11-29 11:30:33,510 - supervised_finetuning - INFO - Epoch 8:
# 2025-11-29 11:30:33,510 - supervised_finetuning - INFO -   Train Loss: 0.6246, Train Acc: 67.72%
# 2025-11-29 11:30:33,510 - supervised_finetuning - INFO -   Train F1: 67.70%, Train Recall: 67.72%
# 2025-11-29 11:30:33,510 - supervised_finetuning - INFO -   Train Precision: 67.71%
# 2025-11-29 11:30:33,510 - supervised_finetuning - INFO - Epoch 7 - supervised_loss/epoch: 0.6246
# 2025-11-29 11:30:33,510 - supervised_finetuning - INFO - Epoch 7 - supervised_accuracy/epoch: 67.7231
# 2025-11-29 11:30:33,510 - supervised_finetuning - INFO - Epoch 7 - supervised_f1/epoch: 67.7032
# 2025-11-29 11:30:33,511 - supervised_finetuning - INFO - Epoch 7 - supervised_recall/epoch: 67.7231
# 2025-11-29 11:30:33,511 - supervised_finetuning - INFO - Epoch 7 - supervised_precision/epoch: 67.7106
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:36,055 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 67.72%
# Classifier Epoch 9/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6108, Acc=75.00%]2025-11-29 11:30:36,067 - supervised_finetuning - INFO - Epoch 152 - supervised_loss/batch: 0.6108
# 2025-11-29 11:30:36,067 - supervised_finetuning - INFO - Epoch 152 - supervised_accuracy/batch: 75.0000
# 2025-11-29 11:30:36,067 - supervised_finetuning - INFO - Epoch 152 - learning_rate: 0.0001
# Classifier Epoch 9/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5917, Acc=68.75%]2025-11-29 11:30:36,126 - supervised_finetuning - INFO - Epoch 162 - supervised_loss/batch: 0.5917
# 2025-11-29 11:30:36,126 - supervised_finetuning - INFO - Epoch 162 - supervised_accuracy/batch: 68.7500
# 2025-11-29 11:30:36,127 - supervised_finetuning - INFO - Epoch 162 - learning_rate: 0.0001
# Classifier Epoch 9/100: 100% 19/19 [00:00<00:00, 169.51it/s, Loss=0.6595, Acc=59.57%]
# 2025-11-29 11:30:36,185 - supervised_finetuning - INFO - Epoch 9:
# 2025-11-29 11:30:36,185 - supervised_finetuning - INFO -   Train Loss: 0.6176, Train Acc: 68.14%
# 2025-11-29 11:30:36,185 - supervised_finetuning - INFO -   Train F1: 68.14%, Train Recall: 68.14%
# 2025-11-29 11:30:36,185 - supervised_finetuning - INFO -   Train Precision: 68.25%
# 2025-11-29 11:30:36,186 - supervised_finetuning - INFO - Epoch 8 - supervised_loss/epoch: 0.6176
# 2025-11-29 11:30:36,186 - supervised_finetuning - INFO - Epoch 8 - supervised_accuracy/epoch: 68.1401
# 2025-11-29 11:30:36,186 - supervised_finetuning - INFO - Epoch 8 - supervised_f1/epoch: 68.1409
# 2025-11-29 11:30:36,186 - supervised_finetuning - INFO - Epoch 8 - supervised_recall/epoch: 68.1401
# 2025-11-29 11:30:36,186 - supervised_finetuning - INFO - Epoch 8 - supervised_precision/epoch: 68.2513
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:36,827 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 68.14%
# Classifier Epoch 10/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5988, Acc=65.62%]2025-11-29 11:30:36,833 - supervised_finetuning - INFO - Epoch 171 - supervised_loss/batch: 0.5988
# 2025-11-29 11:30:36,834 - supervised_finetuning - INFO - Epoch 171 - supervised_accuracy/batch: 65.6250
# 2025-11-29 11:30:36,834 - supervised_finetuning - INFO - Epoch 171 - learning_rate: 0.0001
# Classifier Epoch 10/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6283, Acc=65.62%]2025-11-29 11:30:36,886 - supervised_finetuning - INFO - Epoch 181 - supervised_loss/batch: 0.6283
# 2025-11-29 11:30:36,886 - supervised_finetuning - INFO - Epoch 181 - supervised_accuracy/batch: 65.6250
# 2025-11-29 11:30:36,886 - supervised_finetuning - INFO - Epoch 181 - learning_rate: 0.0001
# Classifier Epoch 10/100: 100% 19/19 [00:00<00:00, 206.11it/s, Loss=0.6076, Acc=63.83%]
# 2025-11-29 11:30:36,935 - supervised_finetuning - INFO - Epoch 10:
# 2025-11-29 11:30:36,935 - supervised_finetuning - INFO -   Train Loss: 0.6062, Train Acc: 67.89%
# 2025-11-29 11:30:36,935 - supervised_finetuning - INFO -   Train F1: 67.89%, Train Recall: 67.89%
# 2025-11-29 11:30:36,935 - supervised_finetuning - INFO -   Train Precision: 68.02%
# 2025-11-29 11:30:36,935 - supervised_finetuning - INFO - Epoch 9 - supervised_loss/epoch: 0.6062
# 2025-11-29 11:30:36,935 - supervised_finetuning - INFO - Epoch 9 - supervised_accuracy/epoch: 67.8899
# 2025-11-29 11:30:36,936 - supervised_finetuning - INFO - Epoch 9 - supervised_f1/epoch: 67.8883
# 2025-11-29 11:30:36,936 - supervised_finetuning - INFO - Epoch 9 - supervised_recall/epoch: 67.8899
# 2025-11-29 11:30:36,936 - supervised_finetuning - INFO - Epoch 9 - supervised_precision/epoch: 68.0160
# Classifier Epoch 11/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6632, Acc=67.19%]2025-11-29 11:30:36,941 - supervised_finetuning - INFO - Epoch 190 - supervised_loss/batch: 0.6632
# 2025-11-29 11:30:36,941 - supervised_finetuning - INFO - Epoch 190 - supervised_accuracy/batch: 67.1875
# 2025-11-29 11:30:36,941 - supervised_finetuning - INFO - Epoch 190 - learning_rate: 0.0001
# Classifier Epoch 11/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5662, Acc=70.31%]2025-11-29 11:30:36,985 - supervised_finetuning - INFO - Epoch 200 - supervised_loss/batch: 0.5662
# 2025-11-29 11:30:36,985 - supervised_finetuning - INFO - Epoch 200 - supervised_accuracy/batch: 70.3125
# 2025-11-29 11:30:36,985 - supervised_finetuning - INFO - Epoch 200 - learning_rate: 0.0001
# Classifier Epoch 11/100: 100% 19/19 [00:00<00:00, 225.34it/s, Loss=0.6127, Acc=72.34%]
# 2025-11-29 11:30:37,036 - supervised_finetuning - INFO - Epoch 11:
# 2025-11-29 11:30:37,036 - supervised_finetuning - INFO -   Train Loss: 0.6007, Train Acc: 68.89%
# 2025-11-29 11:30:37,036 - supervised_finetuning - INFO -   Train F1: 68.88%, Train Recall: 68.89%
# 2025-11-29 11:30:37,036 - supervised_finetuning - INFO -   Train Precision: 69.08%
# 2025-11-29 11:30:37,036 - supervised_finetuning - INFO - Epoch 10 - supervised_loss/epoch: 0.6007
# 2025-11-29 11:30:37,036 - supervised_finetuning - INFO - Epoch 10 - supervised_accuracy/epoch: 68.8907
# 2025-11-29 11:30:37,037 - supervised_finetuning - INFO - Epoch 10 - supervised_f1/epoch: 68.8785
# 2025-11-29 11:30:37,037 - supervised_finetuning - INFO - Epoch 10 - supervised_recall/epoch: 68.8907
# 2025-11-29 11:30:37,037 - supervised_finetuning - INFO - Epoch 10 - supervised_precision/epoch: 69.0785
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:37,639 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 68.89%
# Classifier Epoch 12/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5705, Acc=73.44%]2025-11-29 11:30:37,646 - supervised_finetuning - INFO - Epoch 209 - supervised_loss/batch: 0.5705
# 2025-11-29 11:30:37,646 - supervised_finetuning - INFO - Epoch 209 - supervised_accuracy/batch: 73.4375
# 2025-11-29 11:30:37,646 - supervised_finetuning - INFO - Epoch 209 - learning_rate: 0.0001
# Classifier Epoch 12/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5485, Acc=78.12%]2025-11-29 11:30:37,687 - supervised_finetuning - INFO - Epoch 219 - supervised_loss/batch: 0.5485
# 2025-11-29 11:30:37,687 - supervised_finetuning - INFO - Epoch 219 - supervised_accuracy/batch: 78.1250
# 2025-11-29 11:30:37,688 - supervised_finetuning - INFO - Epoch 219 - learning_rate: 0.0001
# Classifier Epoch 12/100: 100% 19/19 [00:00<00:00, 227.52it/s, Loss=0.6237, Acc=63.83%]
# 2025-11-29 11:30:37,738 - supervised_finetuning - INFO - Epoch 12:
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO -   Train Loss: 0.5874, Train Acc: 69.31%
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO -   Train F1: 69.31%, Train Recall: 69.31%
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO -   Train Precision: 69.38%
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO - Epoch 11 - supervised_loss/epoch: 0.5874
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO - Epoch 11 - supervised_accuracy/epoch: 69.3078
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO - Epoch 11 - supervised_f1/epoch: 69.3128
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO - Epoch 11 - supervised_recall/epoch: 69.3078
# 2025-11-29 11:30:37,739 - supervised_finetuning - INFO - Epoch 11 - supervised_precision/epoch: 69.3829
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:38,350 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 69.31%
# Classifier Epoch 13/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6744, Acc=59.38%]2025-11-29 11:30:38,358 - supervised_finetuning - INFO - Epoch 228 - supervised_loss/batch: 0.6744
# 2025-11-29 11:30:38,359 - supervised_finetuning - INFO - Epoch 228 - supervised_accuracy/batch: 59.3750
# 2025-11-29 11:30:38,359 - supervised_finetuning - INFO - Epoch 228 - learning_rate: 0.0001
# Classifier Epoch 13/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.6236, Acc=59.38%]2025-11-29 11:30:38,416 - supervised_finetuning - INFO - Epoch 238 - supervised_loss/batch: 0.6236
# 2025-11-29 11:30:38,417 - supervised_finetuning - INFO - Epoch 238 - supervised_accuracy/batch: 59.3750
# 2025-11-29 11:30:38,417 - supervised_finetuning - INFO - Epoch 238 - learning_rate: 0.0001
# Classifier Epoch 13/100: 100% 19/19 [00:00<00:00, 181.72it/s, Loss=0.5197, Acc=74.47%]
# 2025-11-29 11:30:38,471 - supervised_finetuning - INFO - Epoch 13:
# 2025-11-29 11:30:38,471 - supervised_finetuning - INFO -   Train Loss: 0.5835, Train Acc: 68.14%
# 2025-11-29 11:30:38,471 - supervised_finetuning - INFO -   Train F1: 68.14%, Train Recall: 68.14%
# 2025-11-29 11:30:38,471 - supervised_finetuning - INFO -   Train Precision: 68.14%
# 2025-11-29 11:30:38,471 - supervised_finetuning - INFO - Epoch 12 - supervised_loss/epoch: 0.5835
# 2025-11-29 11:30:38,471 - supervised_finetuning - INFO - Epoch 12 - supervised_accuracy/epoch: 68.1401
# 2025-11-29 11:30:38,472 - supervised_finetuning - INFO - Epoch 12 - supervised_f1/epoch: 68.1416
# 2025-11-29 11:30:38,472 - supervised_finetuning - INFO - Epoch 12 - supervised_recall/epoch: 68.1401
# 2025-11-29 11:30:38,472 - supervised_finetuning - INFO - Epoch 12 - supervised_precision/epoch: 68.1434
# Classifier Epoch 14/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5916, Acc=64.06%]2025-11-29 11:30:38,478 - supervised_finetuning - INFO - Epoch 247 - supervised_loss/batch: 0.5916
# 2025-11-29 11:30:38,478 - supervised_finetuning - INFO - Epoch 247 - supervised_accuracy/batch: 64.0625
# 2025-11-29 11:30:38,479 - supervised_finetuning - INFO - Epoch 247 - learning_rate: 0.0001
# Classifier Epoch 14/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5626, Acc=70.31%]2025-11-29 11:30:38,532 - supervised_finetuning - INFO - Epoch 257 - supervised_loss/batch: 0.5626
# 2025-11-29 11:30:38,532 - supervised_finetuning - INFO - Epoch 257 - supervised_accuracy/batch: 70.3125
# 2025-11-29 11:30:38,533 - supervised_finetuning - INFO - Epoch 257 - learning_rate: 0.0001
# Classifier Epoch 14/100: 100% 19/19 [00:00<00:00, 182.76it/s, Loss=0.5074, Acc=76.60%]
# 2025-11-29 11:30:38,593 - supervised_finetuning - INFO - Epoch 14:
# 2025-11-29 11:30:38,593 - supervised_finetuning - INFO -   Train Loss: 0.5794, Train Acc: 69.56%
# 2025-11-29 11:30:38,593 - supervised_finetuning - INFO -   Train F1: 69.56%, Train Recall: 69.56%
# 2025-11-29 11:30:38,593 - supervised_finetuning - INFO -   Train Precision: 69.65%
# 2025-11-29 11:30:38,593 - supervised_finetuning - INFO - Epoch 13 - supervised_loss/epoch: 0.5794
# 2025-11-29 11:30:38,594 - supervised_finetuning - INFO - Epoch 13 - supervised_accuracy/epoch: 69.5580
# 2025-11-29 11:30:38,594 - supervised_finetuning - INFO - Epoch 13 - supervised_f1/epoch: 69.5616
# 2025-11-29 11:30:38,594 - supervised_finetuning - INFO - Epoch 13 - supervised_recall/epoch: 69.5580
# 2025-11-29 11:30:38,594 - supervised_finetuning - INFO - Epoch 13 - supervised_precision/epoch: 69.6467
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:39,386 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 69.56%
# Classifier Epoch 15/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5881, Acc=71.88%]2025-11-29 11:30:39,392 - supervised_finetuning - INFO - Epoch 266 - supervised_loss/batch: 0.5881
# 2025-11-29 11:30:39,392 - supervised_finetuning - INFO - Epoch 266 - supervised_accuracy/batch: 71.8750
# 2025-11-29 11:30:39,392 - supervised_finetuning - INFO - Epoch 266 - learning_rate: 0.0001
# Classifier Epoch 15/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5007, Acc=73.44%]2025-11-29 11:30:39,433 - supervised_finetuning - INFO - Epoch 276 - supervised_loss/batch: 0.5007
# 2025-11-29 11:30:39,434 - supervised_finetuning - INFO - Epoch 276 - supervised_accuracy/batch: 73.4375
# 2025-11-29 11:30:39,434 - supervised_finetuning - INFO - Epoch 276 - learning_rate: 0.0001
# Classifier Epoch 15/100: 100% 19/19 [00:00<00:00, 248.36it/s, Loss=0.5568, Acc=68.09%]
# 2025-11-29 11:30:39,473 - supervised_finetuning - INFO - Epoch 15:
# 2025-11-29 11:30:39,473 - supervised_finetuning - INFO -   Train Loss: 0.5723, Train Acc: 70.14%
# 2025-11-29 11:30:39,473 - supervised_finetuning - INFO -   Train F1: 70.14%, Train Recall: 70.14%
# 2025-11-29 11:30:39,474 - supervised_finetuning - INFO -   Train Precision: 70.27%
# 2025-11-29 11:30:39,474 - supervised_finetuning - INFO - Epoch 14 - supervised_loss/epoch: 0.5723
# 2025-11-29 11:30:39,474 - supervised_finetuning - INFO - Epoch 14 - supervised_accuracy/epoch: 70.1418
# 2025-11-29 11:30:39,474 - supervised_finetuning - INFO - Epoch 14 - supervised_f1/epoch: 70.1410
# 2025-11-29 11:30:39,474 - supervised_finetuning - INFO - Epoch 14 - supervised_recall/epoch: 70.1418
# 2025-11-29 11:30:39,475 - supervised_finetuning - INFO - Epoch 14 - supervised_precision/epoch: 70.2669
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:40,029 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 70.14%
# Classifier Epoch 16/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5941, Acc=68.75%]2025-11-29 11:30:40,034 - supervised_finetuning - INFO - Epoch 285 - supervised_loss/batch: 0.5941
# 2025-11-29 11:30:40,034 - supervised_finetuning - INFO - Epoch 285 - supervised_accuracy/batch: 68.7500
# 2025-11-29 11:30:40,034 - supervised_finetuning - INFO - Epoch 285 - learning_rate: 0.0001
# Classifier Epoch 16/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5000, Acc=79.69%]2025-11-29 11:30:40,075 - supervised_finetuning - INFO - Epoch 295 - supervised_loss/batch: 0.5000
# 2025-11-29 11:30:40,075 - supervised_finetuning - INFO - Epoch 295 - supervised_accuracy/batch: 79.6875
# 2025-11-29 11:30:40,075 - supervised_finetuning - INFO - Epoch 295 - learning_rate: 0.0001
# Classifier Epoch 16/100: 100% 19/19 [00:00<00:00, 255.79it/s, Loss=0.5918, Acc=70.21%]
# 2025-11-29 11:30:40,116 - supervised_finetuning - INFO - Epoch 16:
# 2025-11-29 11:30:40,116 - supervised_finetuning - INFO -   Train Loss: 0.5573, Train Acc: 70.14%
# 2025-11-29 11:30:40,116 - supervised_finetuning - INFO -   Train F1: 70.14%, Train Recall: 70.14%
# 2025-11-29 11:30:40,117 - supervised_finetuning - INFO -   Train Precision: 70.14%
# 2025-11-29 11:30:40,117 - supervised_finetuning - INFO - Epoch 15 - supervised_loss/epoch: 0.5573
# 2025-11-29 11:30:40,117 - supervised_finetuning - INFO - Epoch 15 - supervised_accuracy/epoch: 70.1418
# 2025-11-29 11:30:40,117 - supervised_finetuning - INFO - Epoch 15 - supervised_f1/epoch: 70.1367
# 2025-11-29 11:30:40,117 - supervised_finetuning - INFO - Epoch 15 - supervised_recall/epoch: 70.1418
# 2025-11-29 11:30:40,117 - supervised_finetuning - INFO - Epoch 15 - supervised_precision/epoch: 70.1351
# Classifier Epoch 17/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5460, Acc=71.88%]2025-11-29 11:30:40,125 - supervised_finetuning - INFO - Epoch 304 - supervised_loss/batch: 0.5460
# 2025-11-29 11:30:40,125 - supervised_finetuning - INFO - Epoch 304 - supervised_accuracy/batch: 71.8750
# 2025-11-29 11:30:40,125 - supervised_finetuning - INFO - Epoch 304 - learning_rate: 0.0001
# Classifier Epoch 17/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5710, Acc=67.19%]2025-11-29 11:30:40,173 - supervised_finetuning - INFO - Epoch 314 - supervised_loss/batch: 0.5710
# 2025-11-29 11:30:40,173 - supervised_finetuning - INFO - Epoch 314 - supervised_accuracy/batch: 67.1875
# 2025-11-29 11:30:40,174 - supervised_finetuning - INFO - Epoch 314 - learning_rate: 0.0001
# Classifier Epoch 17/100: 100% 19/19 [00:00<00:00, 222.95it/s, Loss=0.6567, Acc=61.70%]
# 2025-11-29 11:30:40,213 - supervised_finetuning - INFO - Epoch 17:
# 2025-11-29 11:30:40,213 - supervised_finetuning - INFO -   Train Loss: 0.5387, Train Acc: 72.14%
# 2025-11-29 11:30:40,213 - supervised_finetuning - INFO -   Train F1: 72.15%, Train Recall: 72.14%
# 2025-11-29 11:30:40,213 - supervised_finetuning - INFO -   Train Precision: 72.24%
# 2025-11-29 11:30:40,213 - supervised_finetuning - INFO - Epoch 16 - supervised_loss/epoch: 0.5387
# 2025-11-29 11:30:40,214 - supervised_finetuning - INFO - Epoch 16 - supervised_accuracy/epoch: 72.1435
# 2025-11-29 11:30:40,214 - supervised_finetuning - INFO - Epoch 16 - supervised_f1/epoch: 72.1464
# 2025-11-29 11:30:40,214 - supervised_finetuning - INFO - Epoch 16 - supervised_recall/epoch: 72.1435
# 2025-11-29 11:30:40,214 - supervised_finetuning - INFO - Epoch 16 - supervised_precision/epoch: 72.2396
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:40,861 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 72.14%
# Classifier Epoch 18/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5702, Acc=75.00%]2025-11-29 11:30:40,866 - supervised_finetuning - INFO - Epoch 323 - supervised_loss/batch: 0.5702
# 2025-11-29 11:30:40,867 - supervised_finetuning - INFO - Epoch 323 - supervised_accuracy/batch: 75.0000
# 2025-11-29 11:30:40,867 - supervised_finetuning - INFO - Epoch 323 - learning_rate: 0.0001
# Classifier Epoch 18/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.4720, Acc=79.69%]2025-11-29 11:30:40,906 - supervised_finetuning - INFO - Epoch 333 - supervised_loss/batch: 0.4720
# 2025-11-29 11:30:40,906 - supervised_finetuning - INFO - Epoch 333 - supervised_accuracy/batch: 79.6875
# 2025-11-29 11:30:40,907 - supervised_finetuning - INFO - Epoch 333 - learning_rate: 0.0001
# Classifier Epoch 18/100: 100% 19/19 [00:00<00:00, 250.46it/s, Loss=0.5287, Acc=72.34%]
# 2025-11-29 11:30:40,950 - supervised_finetuning - INFO - Epoch 18:
# 2025-11-29 11:30:40,951 - supervised_finetuning - INFO -   Train Loss: 0.5234, Train Acc: 72.64%
# 2025-11-29 11:30:40,951 - supervised_finetuning - INFO -   Train F1: 72.65%, Train Recall: 72.64%
# 2025-11-29 11:30:40,951 - supervised_finetuning - INFO -   Train Precision: 72.67%
# 2025-11-29 11:30:40,951 - supervised_finetuning - INFO - Epoch 17 - supervised_loss/epoch: 0.5234
# 2025-11-29 11:30:40,951 - supervised_finetuning - INFO - Epoch 17 - supervised_accuracy/epoch: 72.6439
# 2025-11-29 11:30:40,951 - supervised_finetuning - INFO - Epoch 17 - supervised_f1/epoch: 72.6491
# 2025-11-29 11:30:40,951 - supervised_finetuning - INFO - Epoch 17 - supervised_recall/epoch: 72.6439
# 2025-11-29 11:30:40,952 - supervised_finetuning - INFO - Epoch 17 - supervised_precision/epoch: 72.6689
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:41,718 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 72.64%
# Classifier Epoch 19/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5926, Acc=65.62%]2025-11-29 11:30:41,724 - supervised_finetuning - INFO - Epoch 342 - supervised_loss/batch: 0.5926
# 2025-11-29 11:30:41,725 - supervised_finetuning - INFO - Epoch 342 - supervised_accuracy/batch: 65.6250
# 2025-11-29 11:30:41,725 - supervised_finetuning - INFO - Epoch 342 - learning_rate: 0.0001
# Classifier Epoch 19/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5188, Acc=71.88%]2025-11-29 11:30:41,786 - supervised_finetuning - INFO - Epoch 352 - supervised_loss/batch: 0.5188
# 2025-11-29 11:30:41,787 - supervised_finetuning - INFO - Epoch 352 - supervised_accuracy/batch: 71.8750
# 2025-11-29 11:30:41,787 - supervised_finetuning - INFO - Epoch 352 - learning_rate: 0.0001
# Classifier Epoch 19/100: 100% 19/19 [00:00<00:00, 193.53it/s, Loss=0.5166, Acc=68.09%]
# 2025-11-29 11:30:41,827 - supervised_finetuning - INFO - Epoch 19:
# 2025-11-29 11:30:41,827 - supervised_finetuning - INFO -   Train Loss: 0.5133, Train Acc: 73.98%
# 2025-11-29 11:30:41,827 - supervised_finetuning - INFO -   Train F1: 73.92%, Train Recall: 73.98%
# 2025-11-29 11:30:41,827 - supervised_finetuning - INFO -   Train Precision: 74.49%
# 2025-11-29 11:30:41,827 - supervised_finetuning - INFO - Epoch 18 - supervised_loss/epoch: 0.5133
# 2025-11-29 11:30:41,827 - supervised_finetuning - INFO - Epoch 18 - supervised_accuracy/epoch: 73.9783
# 2025-11-29 11:30:41,828 - supervised_finetuning - INFO - Epoch 18 - supervised_f1/epoch: 73.9175
# 2025-11-29 11:30:41,828 - supervised_finetuning - INFO - Epoch 18 - supervised_recall/epoch: 73.9783
# 2025-11-29 11:30:41,828 - supervised_finetuning - INFO - Epoch 18 - supervised_precision/epoch: 74.4882
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:30:42,560 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 73.98%
# Classifier Epoch 20/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.4055, Acc=81.25%]2025-11-29 11:30:42,566 - supervised_finetuning - INFO - Epoch 361 - supervised_loss/batch: 0.4055
# 2025-11-29 11:30:42,567 - supervised_finetuning - INFO - Epoch 361 - supervised_accuracy/batch: 81.2500
# 2025-11-29 11:30:42,567 - supervised_finetuning - INFO - Epoch 361 - learning_rate: 0.0001
# Classifier Epoch 20/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.5202, Acc=68.75%]2025-11-29 11:30:42,604 - supervised_finetuning - INFO - Epoch 371 - supervised_loss/batch: 0.5202
# 2025-11-29 11:30:42,605 - supervised_finetuning - INFO - Epoch 371 - supervised_accuracy/batch: 68.7500
# 2025-11-29 11:30:42,605 - supervised_finetuning - INFO - Epoch 371 - learning_rate: 0.0001
# Classifier Epoch 20/100: 100% 19/19 [00:00<00:00, 262.47it/s, Loss=0.4075, Acc=78.72%]
# 2025-11-29 11:30:42,646 - supervised_finetuning - INFO - Epoch 20:
# 2025-11-29 11:30:42,646 - supervised_finetuning - INFO -   Train Loss: 0.5051, Train Acc: 72.98%
# 2025-11-29 11:30:42,646 - supervised_finetuning - INFO -   Train F1: 72.98%, Train Recall: 72.98%
# 2025-11-29 11:30:42,646 - supervised_finetuning - INFO -   Train Precision: 72.98%
# 2025-11-29 11:30:42,646 - supervised_finetuning - INFO - Epoch 19 - supervised_loss/epoch: 0.5051
# 2025-11-29 11:30:42,647 - supervised_finetuning - INFO - Epoch 19 - supervised_accuracy/epoch: 72.9775
# 2025-11-29 11:30:42,647 - supervised_finetuning - INFO - Epoch 19 - supervised_f1/epoch: 72.9787
# 2025-11-29 11:30:42,647 - supervised_finetuning - INFO - Epoch 19 - supervised_recall/epoch: 72.9775
# 2025-11-29 11:30:42,647 - supervised_finetuning - INFO - Epoch 19 - supervised_precision/epoch: 72.9804
# Classifier Epoch 21/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.4936, Acc=75.00%]2025-11-29 11:30:42,653 - supervised_finetuning - INFO - Epoch 380 - supervised_loss/batch: 0.4936
# 2025-11-29 11:30:42,653 - supervised_finetuning - INFO - Epoch 380 - supervised_accuracy/batch: 75.0000
# 2025-11-29 11:30:42,653 - supervised_finetuning - INFO - Epoch 380 - learning_rate: 0.0001
# Classifier Epoch 21/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.4649, Acc=75.00%]2025-11-29 11:30:42,690 - supervised_finetuning - INFO - Epoch 390 - supervised_loss/batch: 0.4649
# 2025-11-29 11:30:42,691 - supervised_finetuning - INFO - Epoch 390 - supervised_accuracy/batch: 75.0000
# 2025-11-29 11:30:42,691 - supervised_finetuning - INFO - Epoch 390 - learning_rate: 0.0001
# Classifier Epoch 21/100: 100% 19/19 [00:00<00:00, 259.44it/s, Loss=0.5382, Acc=65.96%]
# 2025-11-29 11:30:42,731 - supervised_finetuning - INFO - Epoch 21:
# ...
# 2025-11-29 11:31:23,888 - supervised_finetuning - INFO - Epoch 1729 - supervised_accuracy/batch: 85.9375
# 2025-11-29 11:31:23,888 - supervised_finetuning - INFO - Epoch 1729 - learning_rate: 0.0001
# Classifier Epoch 92/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1723, Acc=93.75%]2025-11-29 11:31:23,925 - supervised_finetuning - INFO - Epoch 1739 - supervised_loss/batch: 0.1723
# 2025-11-29 11:31:23,926 - supervised_finetuning - INFO - Epoch 1739 - supervised_accuracy/batch: 93.7500
# 2025-11-29 11:31:23,926 - supervised_finetuning - INFO - Epoch 1739 - learning_rate: 0.0001
# Classifier Epoch 92/100: 100% 19/19 [00:00<00:00, 265.91it/s, Loss=0.2435, Acc=91.49%]
# 2025-11-29 11:31:23,967 - supervised_finetuning - INFO - Epoch 92:
# 2025-11-29 11:31:23,967 - supervised_finetuning - INFO -   Train Loss: 0.2207, Train Acc: 90.83%
# 2025-11-29 11:31:23,967 - supervised_finetuning - INFO -   Train F1: 90.83%, Train Recall: 90.83%
# 2025-11-29 11:31:23,967 - supervised_finetuning - INFO -   Train Precision: 90.85%
# 2025-11-29 11:31:23,967 - supervised_finetuning - INFO - Epoch 91 - supervised_loss/epoch: 0.2207
# 2025-11-29 11:31:23,968 - supervised_finetuning - INFO - Epoch 91 - supervised_accuracy/epoch: 90.8257
# 2025-11-29 11:31:23,968 - supervised_finetuning - INFO - Epoch 91 - supervised_f1/epoch: 90.8276
# 2025-11-29 11:31:23,968 - supervised_finetuning - INFO - Epoch 91 - supervised_recall/epoch: 90.8257
# 2025-11-29 11:31:23,968 - supervised_finetuning - INFO - Epoch 91 - supervised_precision/epoch: 90.8542
# Classifier Epoch 93/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1442, Acc=93.75%]2025-11-29 11:31:23,973 - supervised_finetuning - INFO - Epoch 1748 - supervised_loss/batch: 0.1442
# 2025-11-29 11:31:23,974 - supervised_finetuning - INFO - Epoch 1748 - supervised_accuracy/batch: 93.7500
# 2025-11-29 11:31:23,974 - supervised_finetuning - INFO - Epoch 1748 - learning_rate: 0.0001
# Classifier Epoch 93/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.2499, Acc=92.19%]2025-11-29 11:31:24,025 - supervised_finetuning - INFO - Epoch 1758 - supervised_loss/batch: 0.2499
# 2025-11-29 11:31:24,025 - supervised_finetuning - INFO - Epoch 1758 - supervised_accuracy/batch: 92.1875
# 2025-11-29 11:31:24,025 - supervised_finetuning - INFO - Epoch 1758 - learning_rate: 0.0001
# Classifier Epoch 93/100: 100% 19/19 [00:00<00:00, 220.84it/s, Loss=0.1879, Acc=89.36%]
# 2025-11-29 11:31:24,064 - supervised_finetuning - INFO - Epoch 93:
# 2025-11-29 11:31:24,065 - supervised_finetuning - INFO -   Train Loss: 0.2131, Train Acc: 91.24%
# 2025-11-29 11:31:24,065 - supervised_finetuning - INFO -   Train F1: 91.24%, Train Recall: 91.24%
# 2025-11-29 11:31:24,065 - supervised_finetuning - INFO -   Train Precision: 91.27%
# 2025-11-29 11:31:24,065 - supervised_finetuning - INFO - Epoch 92 - supervised_loss/epoch: 0.2131
# 2025-11-29 11:31:24,065 - supervised_finetuning - INFO - Epoch 92 - supervised_accuracy/epoch: 91.2427
# 2025-11-29 11:31:24,065 - supervised_finetuning - INFO - Epoch 92 - supervised_f1/epoch: 91.2444
# 2025-11-29 11:31:24,065 - supervised_finetuning - INFO - Epoch 92 - supervised_recall/epoch: 91.2427
# 2025-11-29 11:31:24,066 - supervised_finetuning - INFO - Epoch 92 - supervised_precision/epoch: 91.2676
# Classifier Epoch 94/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.2709, Acc=85.94%]2025-11-29 11:31:24,070 - supervised_finetuning - INFO - Epoch 1767 - supervised_loss/batch: 0.2709
# 2025-11-29 11:31:24,070 - supervised_finetuning - INFO - Epoch 1767 - supervised_accuracy/batch: 85.9375
# 2025-11-29 11:31:24,070 - supervised_finetuning - INFO - Epoch 1767 - learning_rate: 0.0001
# Classifier Epoch 94/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1631, Acc=93.75%]2025-11-29 11:31:24,106 - supervised_finetuning - INFO - Epoch 1777 - supervised_loss/batch: 0.1631
# 2025-11-29 11:31:24,106 - supervised_finetuning - INFO - Epoch 1777 - supervised_accuracy/batch: 93.7500
# 2025-11-29 11:31:24,107 - supervised_finetuning - INFO - Epoch 1777 - learning_rate: 0.0001
# Classifier Epoch 94/100: 100% 19/19 [00:00<00:00, 275.83it/s, Loss=0.1881, Acc=93.62%]
# 2025-11-29 11:31:24,144 - supervised_finetuning - INFO - Epoch 94:
# 2025-11-29 11:31:24,144 - supervised_finetuning - INFO -   Train Loss: 0.2067, Train Acc: 91.08%
# 2025-11-29 11:31:24,144 - supervised_finetuning - INFO -   Train F1: 91.07%, Train Recall: 91.08%
# 2025-11-29 11:31:24,144 - supervised_finetuning - INFO -   Train Precision: 91.08%
# 2025-11-29 11:31:24,144 - supervised_finetuning - INFO - Epoch 93 - supervised_loss/epoch: 0.2067
# 2025-11-29 11:31:24,144 - supervised_finetuning - INFO - Epoch 93 - supervised_accuracy/epoch: 91.0759
# 2025-11-29 11:31:24,144 - supervised_finetuning - INFO - Epoch 93 - supervised_f1/epoch: 91.0741
# 2025-11-29 11:31:24,145 - supervised_finetuning - INFO - Epoch 93 - supervised_recall/epoch: 91.0759
# 2025-11-29 11:31:24,145 - supervised_finetuning - INFO - Epoch 93 - supervised_precision/epoch: 91.0785
# Classifier Epoch 95/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1644, Acc=93.75%]2025-11-29 11:31:24,149 - supervised_finetuning - INFO - Epoch 1786 - supervised_loss/batch: 0.1644
# 2025-11-29 11:31:24,149 - supervised_finetuning - INFO - Epoch 1786 - supervised_accuracy/batch: 93.7500
# 2025-11-29 11:31:24,150 - supervised_finetuning - INFO - Epoch 1786 - learning_rate: 0.0001
# Classifier Epoch 95/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.2477, Acc=84.38%]2025-11-29 11:31:24,185 - supervised_finetuning - INFO - Epoch 1796 - supervised_loss/batch: 0.2477
# 2025-11-29 11:31:24,186 - supervised_finetuning - INFO - Epoch 1796 - supervised_accuracy/batch: 84.3750
# 2025-11-29 11:31:24,186 - supervised_finetuning - INFO - Epoch 1796 - learning_rate: 0.0001
# Classifier Epoch 95/100: 100% 19/19 [00:00<00:00, 273.22it/s, Loss=0.1747, Acc=95.74%]
# 2025-11-29 11:31:24,224 - supervised_finetuning - INFO - Epoch 95:
# 2025-11-29 11:31:24,224 - supervised_finetuning - INFO -   Train Loss: 0.1994, Train Acc: 91.83%
# 2025-11-29 11:31:24,224 - supervised_finetuning - INFO -   Train F1: 91.83%, Train Recall: 91.83%
# 2025-11-29 11:31:24,224 - supervised_finetuning - INFO -   Train Precision: 91.84%
# 2025-11-29 11:31:24,224 - supervised_finetuning - INFO - Epoch 94 - supervised_loss/epoch: 0.1994
# 2025-11-29 11:31:24,225 - supervised_finetuning - INFO - Epoch 94 - supervised_accuracy/epoch: 91.8265
# 2025-11-29 11:31:24,225 - supervised_finetuning - INFO - Epoch 94 - supervised_f1/epoch: 91.8278
# 2025-11-29 11:31:24,225 - supervised_finetuning - INFO - Epoch 94 - supervised_recall/epoch: 91.8265
# 2025-11-29 11:31:24,225 - supervised_finetuning - INFO - Epoch 94 - supervised_precision/epoch: 91.8372
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:31:29,286 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 91.83%
# Classifier Epoch 96/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.2154, Acc=87.50%]2025-11-29 11:31:29,291 - supervised_finetuning - INFO - Epoch 1805 - supervised_loss/batch: 0.2154
# 2025-11-29 11:31:29,291 - supervised_finetuning - INFO - Epoch 1805 - supervised_accuracy/batch: 87.5000
# 2025-11-29 11:31:29,291 - supervised_finetuning - INFO - Epoch 1805 - learning_rate: 0.0001
# Classifier Epoch 96/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1353, Acc=96.88%]2025-11-29 11:31:29,327 - supervised_finetuning - INFO - Epoch 1815 - supervised_loss/batch: 0.1353
# 2025-11-29 11:31:29,327 - supervised_finetuning - INFO - Epoch 1815 - supervised_accuracy/batch: 96.8750
# 2025-11-29 11:31:29,327 - supervised_finetuning - INFO - Epoch 1815 - learning_rate: 0.0001
# Classifier Epoch 96/100: 100% 19/19 [00:00<00:00, 273.47it/s, Loss=0.1599, Acc=95.74%]
# 2025-11-29 11:31:29,366 - supervised_finetuning - INFO - Epoch 96:
# 2025-11-29 11:31:29,366 - supervised_finetuning - INFO -   Train Loss: 0.1802, Train Acc: 93.08%
# 2025-11-29 11:31:29,366 - supervised_finetuning - INFO -   Train F1: 93.08%, Train Recall: 93.08%
# 2025-11-29 11:31:29,366 - supervised_finetuning - INFO -   Train Precision: 93.10%
# 2025-11-29 11:31:29,366 - supervised_finetuning - INFO - Epoch 95 - supervised_loss/epoch: 0.1802
# 2025-11-29 11:31:29,366 - supervised_finetuning - INFO - Epoch 95 - supervised_accuracy/epoch: 93.0776
# 2025-11-29 11:31:29,367 - supervised_finetuning - INFO - Epoch 95 - supervised_f1/epoch: 93.0789
# 2025-11-29 11:31:29,367 - supervised_finetuning - INFO - Epoch 95 - supervised_recall/epoch: 93.0776
# 2025-11-29 11:31:29,367 - supervised_finetuning - INFO - Epoch 95 - supervised_precision/epoch: 93.1022
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:31:29,920 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 93.08%
# Classifier Epoch 97/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1742, Acc=96.88%]2025-11-29 11:31:29,925 - supervised_finetuning - INFO - Epoch 1824 - supervised_loss/batch: 0.1742
# 2025-11-29 11:31:29,925 - supervised_finetuning - INFO - Epoch 1824 - supervised_accuracy/batch: 96.8750
# 2025-11-29 11:31:29,926 - supervised_finetuning - INFO - Epoch 1824 - learning_rate: 0.0001
# Classifier Epoch 97/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1887, Acc=93.75%]2025-11-29 11:31:29,965 - supervised_finetuning - INFO - Epoch 1834 - supervised_loss/batch: 0.1887
# 2025-11-29 11:31:29,965 - supervised_finetuning - INFO - Epoch 1834 - supervised_accuracy/batch: 93.7500
# 2025-11-29 11:31:29,965 - supervised_finetuning - INFO - Epoch 1834 - learning_rate: 0.0001
# Classifier Epoch 97/100: 100% 19/19 [00:00<00:00, 257.68it/s, Loss=0.2051, Acc=89.36%]
# 2025-11-29 11:31:30,004 - supervised_finetuning - INFO - Epoch 97:
# 2025-11-29 11:31:30,004 - supervised_finetuning - INFO -   Train Loss: 0.1789, Train Acc: 93.58%
# 2025-11-29 11:31:30,004 - supervised_finetuning - INFO -   Train F1: 93.58%, Train Recall: 93.58%
# 2025-11-29 11:31:30,005 - supervised_finetuning - INFO -   Train Precision: 93.58%
# 2025-11-29 11:31:30,005 - supervised_finetuning - INFO - Epoch 96 - supervised_loss/epoch: 0.1789
# 2025-11-29 11:31:30,005 - supervised_finetuning - INFO - Epoch 96 - supervised_accuracy/epoch: 93.5780
# 2025-11-29 11:31:30,005 - supervised_finetuning - INFO - Epoch 96 - supervised_f1/epoch: 93.5781
# 2025-11-29 11:31:30,005 - supervised_finetuning - INFO - Epoch 96 - supervised_recall/epoch: 93.5780
# 2025-11-29 11:31:30,006 - supervised_finetuning - INFO - Epoch 96 - supervised_precision/epoch: 93.5784
# fatal: not a git repository (or any of the parent directories): .git
# 2025-11-29 11:31:35,488 - supervised_finetuning - INFO -   ✓ New best model saved! Train Acc: 93.58%
# Classifier Epoch 98/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.2379, Acc=92.19%]2025-11-29 11:31:35,494 - supervised_finetuning - INFO - Epoch 1843 - supervised_loss/batch: 0.2379
# 2025-11-29 11:31:35,494 - supervised_finetuning - INFO - Epoch 1843 - supervised_accuracy/batch: 92.1875
# 2025-11-29 11:31:35,494 - supervised_finetuning - INFO - Epoch 1843 - learning_rate: 0.0001
# Classifier Epoch 98/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1067, Acc=95.31%]2025-11-29 11:31:35,532 - supervised_finetuning - INFO - Epoch 1853 - supervised_loss/batch: 0.1067
# 2025-11-29 11:31:35,532 - supervised_finetuning - INFO - Epoch 1853 - supervised_accuracy/batch: 95.3125
# 2025-11-29 11:31:35,532 - supervised_finetuning - INFO - Epoch 1853 - learning_rate: 0.0001
# Classifier Epoch 98/100: 100% 19/19 [00:00<00:00, 265.66it/s, Loss=0.2241, Acc=89.36%]
# 2025-11-29 11:31:35,569 - supervised_finetuning - INFO - Epoch 98:
# 2025-11-29 11:31:35,570 - supervised_finetuning - INFO -   Train Loss: 0.1800, Train Acc: 92.91%
# 2025-11-29 11:31:35,570 - supervised_finetuning - INFO -   Train F1: 92.91%, Train Recall: 92.91%
# 2025-11-29 11:31:35,570 - supervised_finetuning - INFO -   Train Precision: 92.94%
# 2025-11-29 11:31:35,570 - supervised_finetuning - INFO - Epoch 97 - supervised_loss/epoch: 0.1800
# 2025-11-29 11:31:35,570 - supervised_finetuning - INFO - Epoch 97 - supervised_accuracy/epoch: 92.9108
# 2025-11-29 11:31:35,570 - supervised_finetuning - INFO - Epoch 97 - supervised_f1/epoch: 92.9122
# 2025-11-29 11:31:35,571 - supervised_finetuning - INFO - Epoch 97 - supervised_recall/epoch: 92.9108
# 2025-11-29 11:31:35,571 - supervised_finetuning - INFO - Epoch 97 - supervised_precision/epoch: 92.9354
# Classifier Epoch 99/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1563, Acc=92.19%]2025-11-29 11:31:35,575 - supervised_finetuning - INFO - Epoch 1862 - supervised_loss/batch: 0.1563
# 2025-11-29 11:31:35,575 - supervised_finetuning - INFO - Epoch 1862 - supervised_accuracy/batch: 92.1875
# 2025-11-29 11:31:35,576 - supervised_finetuning - INFO - Epoch 1862 - learning_rate: 0.0001
# Classifier Epoch 99/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1293, Acc=96.88%]2025-11-29 11:31:35,612 - supervised_finetuning - INFO - Epoch 1872 - supervised_loss/batch: 0.1293
# 2025-11-29 11:31:35,612 - supervised_finetuning - INFO - Epoch 1872 - supervised_accuracy/batch: 96.8750
# 2025-11-29 11:31:35,612 - supervised_finetuning - INFO - Epoch 1872 - learning_rate: 0.0001
# Classifier Epoch 99/100: 100% 19/19 [00:00<00:00, 268.85it/s, Loss=0.1489, Acc=97.87%]
# 2025-11-29 11:31:35,651 - supervised_finetuning - INFO - Epoch 99:
# 2025-11-29 11:31:35,651 - supervised_finetuning - INFO -   Train Loss: 0.1703, Train Acc: 92.99%
# 2025-11-29 11:31:35,651 - supervised_finetuning - INFO -   Train F1: 93.00%, Train Recall: 92.99%
# 2025-11-29 11:31:35,652 - supervised_finetuning - INFO -   Train Precision: 93.07%
# 2025-11-29 11:31:35,652 - supervised_finetuning - INFO - Epoch 98 - supervised_loss/epoch: 0.1703
# 2025-11-29 11:31:35,652 - supervised_finetuning - INFO - Epoch 98 - supervised_accuracy/epoch: 92.9942
# 2025-11-29 11:31:35,652 - supervised_finetuning - INFO - Epoch 98 - supervised_f1/epoch: 92.9954
# 2025-11-29 11:31:35,652 - supervised_finetuning - INFO - Epoch 98 - supervised_recall/epoch: 92.9942
# 2025-11-29 11:31:35,653 - supervised_finetuning - INFO - Epoch 98 - supervised_precision/epoch: 93.0713
# Classifier Epoch 100/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1931, Acc=90.62%]2025-11-29 11:31:35,657 - supervised_finetuning - INFO - Epoch 1881 - supervised_loss/batch: 0.1931
# 2025-11-29 11:31:35,657 - supervised_finetuning - INFO - Epoch 1881 - supervised_accuracy/batch: 90.6250
# 2025-11-29 11:31:35,658 - supervised_finetuning - INFO - Epoch 1881 - learning_rate: 0.0001
# Classifier Epoch 100/100:   0% 0/19 [00:00<?, ?it/s, Loss=0.1903, Acc=93.75%]2025-11-29 11:31:35,705 - supervised_finetuning - INFO - Epoch 1891 - supervised_loss/batch: 0.1903
# 2025-11-29 11:31:35,705 - supervised_finetuning - INFO - Epoch 1891 - supervised_accuracy/batch: 93.7500
# 2025-11-29 11:31:35,706 - supervised_finetuning - INFO - Epoch 1891 - learning_rate: 0.0001
# Classifier Epoch 100/100: 100% 19/19 [00:00<00:00, 188.65it/s, Loss=0.1635, Acc=91.49%]
# 2025-11-29 11:31:35,764 - supervised_finetuning - INFO - Epoch 100:
# 2025-11-29 11:31:35,764 - supervised_finetuning - INFO -   Train Loss: 0.1738, Train Acc: 92.33%
# 2025-11-29 11:31:35,764 - supervised_finetuning - INFO -   Train F1: 92.33%, Train Recall: 92.33%
# 2025-11-29 11:31:35,764 - supervised_finetuning - INFO -   Train Precision: 92.34%
# 2025-11-29 11:31:35,764 - supervised_finetuning - INFO - Epoch 99 - supervised_loss/epoch: 0.1738
# 2025-11-29 11:31:35,765 - supervised_finetuning - INFO - Epoch 99 - supervised_accuracy/epoch: 92.3269
# 2025-11-29 11:31:35,765 - supervised_finetuning - INFO - Epoch 99 - supervised_f1/epoch: 92.3281
# 2025-11-29 11:31:35,765 - supervised_finetuning - INFO - Epoch 99 - supervised_recall/epoch: 92.3269
# 2025-11-29 11:31:35,765 - supervised_finetuning - INFO - Epoch 99 - supervised_precision/epoch: 92.3375
# 2025-11-29 11:31:37,455 - supervised_finetuning - INFO - Supervised fine-tuning completed! Best Train Acc: 93.58%
# 2025-11-29 11:31:37,455 - supervised_finetuning - INFO - ✓ Encoder: FROZEN (contrastive features)
# 2025-11-29 11:31:37,456 - supervised_finetuning - INFO - ✓ Classifier: TRAINED (on label features)
# 2025-11-29 11:31:37,456 - supervised_finetuning - INFO - === TWO-STAGE Supervised Fine-tuning Finished ===

# %% [markdown]
# ## 6. Model Evaluation (2-class dataset)

# %%
# testing / model evaluation:
# !python "/content/SSCLNet-Implementation/eval.py"
# Out:
# 2025-11-29 11:45:20.714711: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764416720.735372   76692 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764416720.741418   76692 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764416720.756860   76692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764416720.756885   76692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764416720.756888   76692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764416720.756892   76692 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-29 11:45:20.761396: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✓ All directories created
# ✓ All directories created
# 2025-11-29 11:45:25,254 - model_evaluation - INFO - === Model Evaluation on Test Set ===
# ================================================================================
# MODEL SUMMARY
# ================================================================================
# Model: SSCLNet
# Total trainable parameters: 25,669,490
# Model size: 98.12 MB
#
# Layer breakdown:
#   encoder.conv1.weight: 3,136
#   encoder.bn1.weight: 64
#   encoder.bn1.bias: 64
#   encoder.layer1.0.conv1.weight: 4,096
#   encoder.layer1.0.bn1.weight: 64
#   encoder.layer1.0.bn1.bias: 64
#   encoder.layer1.0.conv2.weight: 36,864
#   encoder.layer1.0.bn2.weight: 64
#   encoder.layer1.0.bn2.bias: 64
#   encoder.layer1.0.conv3.weight: 16,384
#   encoder.layer1.0.bn3.weight: 256
#   encoder.layer1.0.bn3.bias: 256
#   encoder.layer1.0.downsample.0.weight: 16,384
#   encoder.layer1.0.downsample.1.weight: 256
#   encoder.layer1.0.downsample.1.bias: 256
#   encoder.layer1.1.conv1.weight: 16,384
#   encoder.layer1.1.bn1.weight: 64
#   encoder.layer1.1.bn1.bias: 64
#   encoder.layer1.1.conv2.weight: 36,864
#   encoder.layer1.1.bn2.weight: 64
#   encoder.layer1.1.bn2.bias: 64
#   encoder.layer1.1.conv3.weight: 16,384
#   encoder.layer1.1.bn3.weight: 256
#   encoder.layer1.1.bn3.bias: 256
#   encoder.layer1.2.conv1.weight: 16,384
#   encoder.layer1.2.bn1.weight: 64
#   encoder.layer1.2.bn1.bias: 64
#   encoder.layer1.2.conv2.weight: 36,864
#   encoder.layer1.2.bn2.weight: 64
#   encoder.layer1.2.bn2.bias: 64
#   encoder.layer1.2.conv3.weight: 16,384
#   encoder.layer1.2.bn3.weight: 256
#   encoder.layer1.2.bn3.bias: 256
#   encoder.layer2.0.conv1.weight: 32,768
#   encoder.layer2.0.bn1.weight: 128
#   encoder.layer2.0.bn1.bias: 128
#   encoder.layer2.0.conv2.weight: 147,456
#   encoder.layer2.0.bn2.weight: 128
#   encoder.layer2.0.bn2.bias: 128
#   encoder.layer2.0.conv3.weight: 65,536
#   encoder.layer2.0.bn3.weight: 512
#   encoder.layer2.0.bn3.bias: 512
#   encoder.layer2.0.downsample.0.weight: 131,072
#   encoder.layer2.0.downsample.1.weight: 512
#   encoder.layer2.0.downsample.1.bias: 512
#   encoder.layer2.1.conv1.weight: 65,536
#   encoder.layer2.1.bn1.weight: 128
#   encoder.layer2.1.bn1.bias: 128
#   encoder.layer2.1.conv2.weight: 147,456
#   encoder.layer2.1.bn2.weight: 128
#   encoder.layer2.1.bn2.bias: 128
#   encoder.layer2.1.conv3.weight: 65,536
#   encoder.layer2.1.bn3.weight: 512
#   encoder.layer2.1.bn3.bias: 512
#   encoder.layer2.2.conv1.weight: 65,536
#   encoder.layer2.2.bn1.weight: 128
#   encoder.layer2.2.bn1.bias: 128
#   encoder.layer2.2.conv2.weight: 147,456
#   encoder.layer2.2.bn2.weight: 128
#   encoder.layer2.2.bn2.bias: 128
#   encoder.layer2.2.conv3.weight: 65,536
#   encoder.layer2.2.bn3.weight: 512
#   encoder.layer2.2.bn3.bias: 512
#   encoder.layer2.3.conv1.weight: 65,536
#   encoder.layer2.3.bn1.weight: 128
#   encoder.layer2.3.bn1.bias: 128
#   encoder.layer2.3.conv2.weight: 147,456
#   encoder.layer2.3.bn2.weight: 128
#   encoder.layer2.3.bn2.bias: 128
#   encoder.layer2.3.conv3.weight: 65,536
#   encoder.layer2.3.bn3.weight: 512
#   encoder.layer2.3.bn3.bias: 512
#   encoder.layer3.0.conv1.weight: 131,072
#   encoder.layer3.0.bn1.weight: 256
#   encoder.layer3.0.bn1.bias: 256
#   encoder.layer3.0.conv2.weight: 589,824
#   encoder.layer3.0.bn2.weight: 256
#   encoder.layer3.0.bn2.bias: 256
#   encoder.layer3.0.conv3.weight: 262,144
#   encoder.layer3.0.bn3.weight: 1,024
#   encoder.layer3.0.bn3.bias: 1,024
#   encoder.layer3.0.downsample.0.weight: 524,288
#   encoder.layer3.0.downsample.1.weight: 1,024
#   encoder.layer3.0.downsample.1.bias: 1,024
#   encoder.layer3.1.conv1.weight: 262,144
#   encoder.layer3.1.bn1.weight: 256
#   encoder.layer3.1.bn1.bias: 256
#   encoder.layer3.1.conv2.weight: 589,824
#   encoder.layer3.1.bn2.weight: 256
#   encoder.layer3.1.bn2.bias: 256
#   encoder.layer3.1.conv3.weight: 262,144
#   encoder.layer3.1.bn3.weight: 1,024
#   encoder.layer3.1.bn3.bias: 1,024
#   encoder.layer3.2.conv1.weight: 262,144
#   encoder.layer3.2.bn1.weight: 256
#   encoder.layer3.2.bn1.bias: 256
#   encoder.layer3.2.conv2.weight: 589,824
#   encoder.layer3.2.bn2.weight: 256
#   encoder.layer3.2.bn2.bias: 256
#   encoder.layer3.2.conv3.weight: 262,144
#   encoder.layer3.2.bn3.weight: 1,024
#   encoder.layer3.2.bn3.bias: 1,024
#   encoder.layer3.3.conv1.weight: 262,144
#   encoder.layer3.3.bn1.weight: 256
#   encoder.layer3.3.bn1.bias: 256
#   encoder.layer3.3.conv2.weight: 589,824
#   encoder.layer3.3.bn2.weight: 256
#   encoder.layer3.3.bn2.bias: 256
#   encoder.layer3.3.conv3.weight: 262,144
#   encoder.layer3.3.bn3.weight: 1,024
#   encoder.layer3.3.bn3.bias: 1,024
#   encoder.layer3.4.conv1.weight: 262,144
#   encoder.layer3.4.bn1.weight: 256
#   encoder.layer3.4.bn1.bias: 256
#   encoder.layer3.4.conv2.weight: 589,824
#   encoder.layer3.4.bn2.weight: 256
#   encoder.layer3.4.bn2.bias: 256
#   encoder.layer3.4.conv3.weight: 262,144
#   encoder.layer3.4.bn3.weight: 1,024
#   encoder.layer3.4.bn3.bias: 1,024
#   encoder.layer3.5.conv1.weight: 262,144
#   encoder.layer3.5.bn1.weight: 256
#   encoder.layer3.5.bn1.bias: 256
#   encoder.layer3.5.conv2.weight: 589,824
#   encoder.layer3.5.bn2.weight: 256
#   encoder.layer3.5.bn2.bias: 256
#   encoder.layer3.5.conv3.weight: 262,144
#   encoder.layer3.5.bn3.weight: 1,024
#   encoder.layer3.5.bn3.bias: 1,024
#   encoder.layer4.0.conv1.weight: 524,288
#   encoder.layer4.0.bn1.weight: 512
#   encoder.layer4.0.bn1.bias: 512
#   encoder.layer4.0.conv2.weight: 2,359,296
#   encoder.layer4.0.bn2.weight: 512
#   encoder.layer4.0.bn2.bias: 512
#   encoder.layer4.0.conv3.weight: 1,048,576
#   encoder.layer4.0.bn3.weight: 2,048
#   encoder.layer4.0.bn3.bias: 2,048
#   encoder.layer4.0.downsample.0.weight: 2,097,152
#   encoder.layer4.0.downsample.1.weight: 2,048
#   encoder.layer4.0.downsample.1.bias: 2,048
#   encoder.layer4.1.conv1.weight: 1,048,576
#   encoder.layer4.1.bn1.weight: 512
#   encoder.layer4.1.bn1.bias: 512
#   encoder.layer4.1.conv2.weight: 2,359,296
#   encoder.layer4.1.bn2.weight: 512
#   encoder.layer4.1.bn2.bias: 512
#   encoder.layer4.1.conv3.weight: 1,048,576
#   encoder.layer4.1.bn3.weight: 2,048
#   encoder.layer4.1.bn3.bias: 2,048
#   encoder.layer4.2.conv1.weight: 1,048,576
#   encoder.layer4.2.bn1.weight: 512
#   encoder.layer4.2.bn1.bias: 512
#   encoder.layer4.2.conv2.weight: 2,359,296
#   encoder.layer4.2.bn2.weight: 512
#   encoder.layer4.2.bn2.bias: 512
#   encoder.layer4.2.conv3.weight: 1,048,576
#   encoder.layer4.2.bn3.weight: 2,048
#   encoder.layer4.2.bn3.bias: 2,048
#   projection_head.mlp.0.weight: 1,048,576
#   projection_head.mlp.0.bias: 512
#   projection_head.mlp.2.weight: 262,144
#   projection_head.mlp.2.bias: 512
#   projection_head.mlp.4.weight: 131,072
#   projection_head.mlp.4.bias: 256
#   projection_head.mlp.6.weight: 65,536
#   projection_head.mlp.6.bias: 256
#   projection_head.mlp.9.weight: 8,192
#   projection_head.mlp.9.bias: 32
#   classifier.classifier.0.weight: 524,288
#   classifier.classifier.0.bias: 256
#   classifier.classifier.2.weight: 65,536
#   classifier.classifier.2.bias: 256
#   classifier.classifier.4.weight: 32,768
#   classifier.classifier.4.bias: 128
#   classifier.classifier.6.weight: 16,384
#   classifier.classifier.6.bias: 128
#   classifier.classifier.8.weight: 8,192
#   classifier.classifier.8.bias: 64
#   classifier.classifier.10.weight: 2,048
#   classifier.classifier.10.bias: 32
#   classifier.classifier.12.weight: 512
#   classifier.classifier.12.bias: 16
#   classifier.classifier.14.weight: 32
#   classifier.classifier.14.bias: 2
# ================================================================================
# Created test DataLoader:
#   - Batch size: 64
#   - Shuffle: False
#   - Workers: 2
#   - Classes: ['no', 'yes']
#   - Number of samples: 616
# ==================================================
# DATASET ANALYSIS
# ==================================================
# Total samples: 616
# Class distribution:
#   no: 317 (51.5%)
#   yes: 299 (48.5%)
# 2025-11-29 11:45:26,851 - model_evaluation - INFO - Evaluating on 616 test samples
# 2025-11-29 11:45:26,852 - model_evaluation - INFO - Running evaluation on test set...
# 2025-11-29 11:45:28,972 - model_evaluation - INFO - Processed 10/10 batches
# 2025-11-29 11:45:29,015 - model_evaluation - INFO -
# ==================================================
# 2025-11-29 11:45:29,015 - model_evaluation - INFO - FINAL TEST RESULTS
# 2025-11-29 11:45:29,015 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:45:29,016 - model_evaluation - INFO - Test Loss: 0.4096
# 2025-11-29 11:45:29,016 - model_evaluation - INFO - Test Accuracy: 83.60%
# 2025-11-29 11:45:29,016 - model_evaluation - INFO - Test Precision: 83.61%
# 2025-11-29 11:45:29,016 - model_evaluation - INFO - Test Recall: 83.60%
# 2025-11-29 11:45:29,016 - model_evaluation - INFO - Test F1-Score: 83.60%
# 2025-11-29 11:45:29,016 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:45:29,016 - model_evaluation - INFO -
# DETAILED CLASSIFICATION REPORT:
# 2025-11-29 11:45:29,016 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:45:29,024 - model_evaluation - INFO -
#               precision    recall  f1-score   support
#
#           no       0.84      0.84      0.84       317
#          yes       0.83      0.83      0.83       299
#
#     accuracy                           0.84       616
#    macro avg       0.84      0.84      0.84       616
# weighted avg       0.84      0.84      0.84       616
#
# 2025-11-29 11:45:29,024 - model_evaluation - INFO -
# CONFUSION MATRIX:
# 2025-11-29 11:45:29,024 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:45:29,025 - model_evaluation - INFO -
# [[266  51]
#  [ 50 249]]
# 2025-11-29 11:45:29,400 - model_evaluation - INFO - Confusion matrix saved as 'plots/confusion_matrix.png'
# 2025-11-29 11:45:29,400 - model_evaluation - INFO -
# ==================================================
# 2025-11-29 11:45:29,400 - model_evaluation - INFO - ROC CURVE ANALYSIS
# 2025-11-29 11:45:29,400 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:45:29,980 - model_evaluation - INFO - ROC curve saved as 'plots/roc_curve.png'
# 2025-11-29 11:45:29,981 - model_evaluation - INFO -
# AUC Score: 0.9156
# 2025-11-29 11:45:29,981 - model_evaluation - INFO -
# PER-CLASS ACCURACY:
# 2025-11-29 11:45:29,981 - model_evaluation - INFO - ==================================================
# 2025-11-29 11:45:29,981 - model_evaluation - INFO - no: 83.91%
# 2025-11-29 11:45:29,981 - model_evaluation - INFO - yes: 83.28%
# 2025-11-29 11:45:29,981 - model_evaluation - INFO - === Model Evaluation Completed ===
# fatal: not a git repository (or any of the parent directories): .git
# ✓ Results saved to: results/final_evaluation_results.json
#
# ✓ Evaluation completed! Check:
#   - logs/model_evaluation.log for detailed logs
#   - results/final_evaluation_results.json for comprehensive results
#   - plots/ for confusion matrix and ROC curves

# %%
# !zip -r /content/plots_2Class.zip /content/plots
# !zip -r /content/results_2Class.zip /content/results
# !zip -r /content/logs_2Class.zip /content/logs
# Out:
#   adding: content/plots/ (stored 0%)
#   adding: content/plots/contrastive_loss.png (deflated 24%)
#   adding: content/plots/roc_curve.png (deflated 24%)
#   adding: content/plots/class_distribution.png (deflated 41%)
#   adding: content/plots/confusion_matrix.png (deflated 25%)
#   adding: content/plots/supervised_training_history.png (deflated 25%)
#   adding: content/results/ (stored 0%)
#   adding: content/results/test_results.txt (deflated 40%)
#   adding: content/results/final_evaluation_results.json (deflated 53%)
#   adding: content/logs/ (stored 0%)
#   adding: content/logs/supervised_finetuning.log (deflated 91%)
#   adding: content/logs/contrastive_pretraining.log (deflated 89%)
#   adding: content/logs/model_evaluation.log (deflated 88%)
